# %% [markdown]
# Student DB: Create a PANDAS dataframe for a university database holding student information
#
# The database should contain the student's ID, name, field of study and number of semesters
#
# Print your data frame

# %%
import pandas as pd

student_df = pd.DataFrame({
    'ID': [101, 102, 103, 104],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Field of Study': ['Math', 'Physics', 'Chemistry', 'Biology'],
    'Number of Semesters': [5, 3, 6, 3]
})
print(student_df)
# Out:
#     ID     Name Field of Study  Number of Semesters
# 0  101    Alice           Math                    5
# 1  102      Bob        Physics                    3
# 2  103  Charlie      Chemistry                    6
# 3  104    David        Biology                    3

# %% [markdown]
# Perform the following operations on your data frame and check the result:
# - Select columns "ID" and "Name"
# - Create a new column adding one semester to the existing number of semesters
# - Permanently drop the new column again

# %%
print(student_df[['ID', 'Name']])

student_df['Increased Semesters'] = student_df['Number of Semesters'] + 1
print(student_df)

student_df.drop(columns=['Increased Semesters'], inplace=True)
print(student_df)
# Out:
#     ID     Name
# 0  101    Alice
# 1  102      Bob
# 2  103  Charlie
# 3  104    David
#     ID     Name Field of Study  Number of Semesters  Increased Semesters
# 0  101    Alice           Math                    5                    6
# 1  102      Bob        Physics                    3                    4
# 2  103  Charlie      Chemistry                    6                    7
# 3  104    David        Biology                    3                    4
#     ID     Name Field of Study  Number of Semesters
# 0  101    Alice           Math                    5
# 1  102      Bob        Physics                    3
# 2  103  Charlie      Chemistry                    6
# 3  104    David        Biology                    3

# %% [markdown]
# Perform the following operations on your data frame and check the result:
# - Select all columns for one specific student
# - Show the name of all students in a specific semester (without directly selecting one row)

# %%
print(student_df.loc[2])

print(student_df[student_df['Number of Semesters'] == 3]['Name'])
# Out:
# ID                           103
# Name                     Charlie
# Field of Study         Chemistry
# Number of Semesters            6
# Name: 2, dtype: object
# 1      Bob
# 3    David
# Name: Name, dtype: object
