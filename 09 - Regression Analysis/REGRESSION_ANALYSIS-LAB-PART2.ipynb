# %% [markdown]
# # Task 1: Load Data

# %% [markdown]
# Load preprared training and test data

# %%
import pandas as pd

df_train = pd.read_csv('Training.CSV')
df_test = pd.read_csv('Test.CSV')

# %%
#Check shape and content of training data
df_train
# Out:
#       Unnamed: 0  MedInc  AveRooms  Latitude  HouseAge  AveBedrms  Longitude  \
# 0              0  8.3252  6.984127     37.88      41.0   1.023810    -122.23
# 1              1  8.3014  6.238137     37.86      21.0   0.971880    -122.22
# 2              2  7.2574  8.288136     37.85      52.0   1.073446    -122.24
# 3              3  5.6431  5.817352     37.85      52.0   1.073059    -122.25
# 4              4  3.8462  6.281853     37.85      52.0   1.081081    -122.25
# ...          ...     ...       ...       ...       ...        ...        ...
# 6995        6995  3.1170  4.876033     33.96      37.0   1.057851    -118.03
# 6996        6996  3.6509  5.018667     33.95      34.0   1.141333    -118.03
# 6997        6997  4.1471  5.435583     33.95      37.0   0.984663    -118.03
# 6998        6998  3.8214  5.600823     33.95      36.0   1.059671    -118.04
# 6999        6999  3.2250  5.139842     33.96      37.0   1.042216    -118.04
#
#       Label
# 0     4.526
# 1     3.585
# ...

# %%
#Check shape and content of test data
df_test
# Out:
#       Unnamed: 0  MedInc  AveRooms  Latitude  HouseAge  AveBedrms  Longitude  \
# 0           7000  3.3214  4.454829     33.96      42.0   1.052960    -118.04
# 1           7001  2.9714  4.071429     33.96      37.0   1.012422    -118.05
# 2           7002  3.0491  4.498721     33.97      34.0   1.102302    -118.04
# 3           7003  4.0379  5.275862     33.98      34.0   0.960591    -118.05
# 4           7004  3.6000  4.240713     33.97      36.0   1.022288    -118.05
# ...          ...     ...       ...       ...       ...        ...        ...
# 2995        9995  4.0775  6.140900     39.14      10.0   1.025440    -121.03
# 2996        9996  4.0848  6.350394     39.13       8.0   1.091864    -121.07
# 2997        9997  3.6333  7.243455     39.11       7.0   1.107330    -121.05
# 2998        9998  3.4630  6.363636     39.08       8.0   1.166297    -121.04
# 2999        9999  3.0781  5.487500     39.09       7.0   1.050000    -121.00
#
#       Label
# 0     1.488
# 1     1.603
# ...

# %% [markdown]
# # Task 2: Prepare Data

# %%
#Remove first column from both data frames and check result
df_train=df_train[] #<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
df_test=#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
# Out:
#   Cell In[4], line 2
#     df_train=#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
#              ^
# SyntaxError: invalid syntax

# %%
#check result
#df_train
df_test
# Out:
#       MedInc  AveRooms  Latitude  HouseAge  AveBedrms  Longitude  Label
# 0     3.3214  4.454829     33.96      42.0   1.052960    -118.04  1.488
# 1     2.9714  4.071429     33.96      37.0   1.012422    -118.05  1.603
# 2     3.0491  4.498721     33.97      34.0   1.102302    -118.04  1.582
# 3     4.0379  5.275862     33.98      34.0   0.960591    -118.05  1.728
# 4     3.6000  4.240713     33.97      36.0   1.022288    -118.05  1.540
# ...      ...       ...       ...       ...        ...        ...    ...
# 2995  4.0775  6.140900     39.14      10.0   1.025440    -121.03  1.645
# 2996  4.0848  6.350394     39.13       8.0   1.091864    -121.07  1.559
# 2997  3.6333  7.243455     39.11       7.0   1.107330    -121.05  1.702
# 2998  3.4630  6.363636     39.08       8.0   1.166297    -121.04  2.017
# 2999  3.0781  5.487500     39.09       7.0   1.050000    -121.00  1.625
#
# [3000 rows x 7 columns]

# %%
#Split data into features and labels again (see previous lab)
#Training Data
train_features=df_train.iloc#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
train_labels=df_train.iloc#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>

#Test Data (the remaining examples)
#Add lines of code to create test data (features and labels)
test_features=df_test.iloc#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
test_labels=df_test.iloc#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>

# %%
#Cheeck results
#train_features
#train_labels
#test_features
test_labels
# Out:
# 0       1.488
# 1       1.603
# 2       1.582
# 3       1.728
# 4       1.540
#         ...
# 2995    1.645
# 2996    1.559
# 2997    1.702
# 2998    2.017
# 2999    1.625
# Name: Label, Length: 3000, dtype: float64

# %% [markdown]
# # Task 3: Model Building and Evaluation

# %%
#Build Linear Regression Model using the training data
from sklearn import linear_model
#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>

#Fit regression model to training data
#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
# Out:
# LinearRegression()

# %%
#Predict all test examples
ypred = #<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>

# %%
#Evaluate linear regression model with test data using Mean Absolute Error
from sklearn.metrics import mean_absolute_error

mae = #<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.602

# %%
#Check p-values using statsmodels
import statsmodels.api as sm
from scipy import stats

X = #<<<<<<<<<<<<<<<<<<<< add coding here >>>>>>>>>>>>>>>>>>>>>>>>>
y = #<<<<<<<<<<<<<<<<<<<< add coding here >>>>>>>>>>>>>>>>>>>>>>>>>

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())

# %% [markdown]
# # Task 4: Algorithm Selection and Model Tuning

# %%
#Build KNN Regression Model using the training data and standard parametrization
from sklearn.neighbors import KNeighborsRegressor
#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>

#Fit regression model to training data
#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
# Out:
# KNeighborsRegressor()

# %%
#Predict all test examples
ypred = #<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>

#Evaluate KNN regression model with test data using Mean Absolute Error
#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.612

# %% [markdown]
# Build a function, which receives the number of neighbors as an argument!
#
# The function should
# - set the KNN regressor to the defined number of neighbors,
# - build a model with this setting using the training data,
# - predict values for the test data and
# - calculate and print the MAE

# %%
def tune_and_evaluate_knn_reg(number_of_neighbors):
    #Use the method set_params to set the number of neighbors
    #<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
    #Fit regression model to training data
    KNN_reg.fit(train_features,train_labels)
    #Predict all test examples
    ypred = KNN_reg.predict(test_features)
    #Evaluate KNN regression model with test data using Mean Absolute Error
    mae = mean_absolute_error(test_labels, ypred)
    print('MAE: %.3f' % mae)

# %%
#call your funtion with number of neighbors = 10
#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
# Out:
# MAE: 0.604

# %% [markdown]
# Experiment with other values for the number of neighbors to find an optimum!

# %%
#<<<<<<<<<<<<<<<<<<< add code here >>>>>>>>>>>>>>>
# Out:
# Number of neighbors:  1
# MAE: 0.703
# Number of neighbors:  2
# MAE: 0.640
# Number of neighbors:  3
# MAE: 0.625
# Number of neighbors:  4
# MAE: 0.616
# Number of neighbors:  5
# MAE: 0.612
# Number of neighbors:  6
# MAE: 0.608
# Number of neighbors:  7
# MAE: 0.604
# Number of neighbors:  8
# MAE: 0.604
# Number of neighbors:  9
# MAE: 0.605
# Number of neighbors:  10
# MAE: 0.604
# Number of neighbors:  11
# MAE: 0.603
# Number of neighbors:  12
# MAE: 0.602
# Number of neighbors:  13
# MAE: 0.603
# Number of neighbors:  14
# MAE: 0.602
# Number of neighbors:  15
# MAE: 0.602
# Number of neighbors:  16
# MAE: 0.603
# Number of neighbors:  17
# MAE: 0.603
# Number of neighbors:  18
# MAE: 0.603
# Number of neighbors:  19
# MAE: 0.602
# Number of neighbors:  20
# MAE: 0.603
