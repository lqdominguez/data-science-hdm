# %% [markdown]
# # Load, explore and prepare data set

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

sns. set_style('whitegrid')
titanic = sns. load_dataset('titanic')

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#remove label "survived" from data frame and store it seperately
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>

# %%
#store numeric features in a dataframe
titanic_numeric=#<<<<<<<<<<<<<<< enter code here >>>>>>>>>>>>>>>>>>
#store nominal features in a dataframe
titanic_nominal=#<<<<<<<<<<<<<<< enter code here >>>>>>>>>>>>>>>>>>
# Out:
# C:\Users\HENDRI~1\AppData\Local\Temp/ipykernel_23936/2704845850.py:4: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   titanic_nominal=titanic.select_dtypes(include=np.object)

# %%
#show descriptive statistics for numeric features
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
# Out:
#            pclass         age       sibsp       parch        fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#replace missing values by median
titanic_numeric['age'] = titanic_numeric['age'].fillna(titanic_numeric['age'].median())

#show descriptive statistics for numeric features
titanic_numeric.describe()
# Out:
# C:\Users\HENDRI~1\AppData\Local\Temp/ipykernel_23936/3232013458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_numeric['age'] = titanic_numeric['age'].fillna(titanic_numeric['age'].median())
#            pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.836071   13.019697    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#show descriptive statistics for nominal features
titanic_nominal.describe()
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
#remove feature "alive"
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
titanic_nominal
# Out:
#         sex embarked    who  embark_town
# 0      male        S    man  Southampton
# 1    female        C  woman    Cherbourg
# 2    female        S  woman  Southampton
# 3    female        S  woman  Southampton
# 4      male        S    man  Southampton
# ..      ...      ...    ...          ...
# 886    male        S    man  Southampton
# 887  female        S  woman  Southampton
# 888  female        S  woman  Southampton
# 889    male        C    man    Cherbourg
# 890    male        Q    man   Queenstown
#
# [891 rows x 4 columns]

# %%
#Show unique values for all nominal features
#use a for loop and the data frame attribute "columns"
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
# Out:
# sex  unique values:  ['male' 'female']
# embarked  unique values:  ['S' 'C' 'Q' nan]
# who  unique values:  ['man' 'woman' 'child']
# embark_town  unique values:  ['Southampton' 'Cherbourg' 'Queenstown' nan]

# %%
#Show histograms of numeric features
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
plt.show()

# %% [markdown]
# # Feature selection by variance and variation ratio

# %% [markdown]
# Numeric features

# %%
#min-max normalize numeric features
#min value should be 0, max value should be 100
from sklearn.preprocessing import MinMaxScaler
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
titanic_numeric = #<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
#show descriptive statistics for normalized features
titanic_numeric.describe()
# Out:
#            pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    65.432099   36.367910    6.537598    6.359895    6.285843
# std     41.803562   16.360513   13.784293   13.434287    9.699511
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     50.000000   27.117366    0.000000    0.000000    1.544007
# 50%    100.000000   34.656949    0.000000    0.000000    2.821272
# 75%    100.000000   43.453129   12.500000    0.000000    6.050797
# max    100.000000  100.000000  100.000000  100.000000  100.000000

# %%
#calculate standard deviation of numeric features and show them
numeric_features_std = titanic_numeric.std()
numeric_features_std
# Out:
# pclass    41.803562
# age       16.360513
# sibsp     13.784293
# parch     13.434287
# fare       9.699511
# dtype: float64

# %%
#remove numeric features with standard deviation < 10
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
titanic_numeric
# Out:
#      pclass        age  sibsp      parch
# 0     100.0  27.117366   12.5   0.000000
# 1       0.0  47.222920   12.5   0.000000
# 2     100.0  32.143755    0.0   0.000000
# 3       0.0  43.453129   12.5   0.000000
# 4     100.0  43.453129    0.0   0.000000
# ..      ...        ...    ...        ...
# 886    50.0  33.400352    0.0   0.000000
# 887     0.0  23.347575    0.0   0.000000
# 888   100.0  34.656949   12.5  33.333333
# 889     0.0  32.143755    0.0   0.000000
# 890   100.0  39.683338    0.0   0.000000
#
# [891 rows x 4 columns]

# %% [markdown]
# Nominal features

# %%
#calculate variation ratio for nominal features
#explanation: The value_counts() method counts the number of occurrences of each unique value in the column, 
#and the normalize=True parameter normalizes the counts to represent percentages of the total number of values in the column
nominal_features_var = titanic_nominal.apply(lambda x: x.value_counts(normalize=True).max(), axis=0)
nominal_features_var_ratio=1-nominal_features_var
nominal_features_var_ratio
# Out:
# sex            0.352413
# embarked       0.275591
# who            0.397306
# embark_town    0.275591
# dtype: float64

# %%
#remove nominal features with variation ratio < 0.3
titanic_nominal = #<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
titanic_nominal
# Out:
#         sex    who
# 0      male    man
# 1    female  woman
# 2    female  woman
# 3    female  woman
# 4      male    man
# ..      ...    ...
# 886    male    man
# 887  female  woman
# 888  female  woman
# 889    male    man
# 890    male    man
#
# [891 rows x 2 columns]

# %% [markdown]
# # Feature selection using correlation and colinearity

# %%
#apply target transformation to all nominal features
#apply a for loop and add the target encoded features to "titanic_numeric"
titanic_nominal_label=titanic_nominal.copy()
titanic_nominal_label['label']=label
columns=titanic_nominal.columns

#<<<<<<<<<<<<<<< enter lines of code here >>>>>>>>>>>>>>>>>>

#display titanic_numeric
titanic_numeric
# Out:
# Index(['sex', 'who'], dtype='object')
#      pclass        age  sibsp      parch    sex_TE    who_TE
# 0     100.0  27.117366   12.5   0.000000  0.188908  0.163873
# 1       0.0  47.222920   12.5   0.000000  0.742038  0.756458
# 2     100.0  32.143755    0.0   0.000000  0.742038  0.756458
# 3       0.0  43.453129   12.5   0.000000  0.742038  0.756458
# 4     100.0  43.453129    0.0   0.000000  0.188908  0.163873
# ..      ...        ...    ...        ...       ...       ...
# 886    50.0  33.400352    0.0   0.000000  0.188908  0.163873
# 887     0.0  23.347575    0.0   0.000000  0.742038  0.756458
# 888   100.0  34.656949   12.5  33.333333  0.742038  0.756458
# 889     0.0  32.143755    0.0   0.000000  0.188908  0.163873
# 890   100.0  39.683338    0.0   0.000000  0.188908  0.163873
#
# [891 rows x 6 columns]

# %%
#calculate correlation of numeric features with label
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
titanic_numeric_corr
# Out:
# pclass   -0.338481
# age      -0.064910
# sibsp    -0.035322
# parch     0.081629
# sex_TE    0.543351
# who_TE    0.564497
# dtype: float64

# %%
#keep 5 best numeric features
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
#re-calculate correlations with label
titanic_numeric_corr = titanic_numeric.corrwith(label)
titanic_numeric_corr
# Out:
# who_TE    0.564497
# sex_TE    0.543351
# pclass   -0.338481
# parch     0.081629
# age      -0.064910
# dtype: float64

# %%
#calculate colinearity of remaining numeric features
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
# Displaying correlations as a heatmap / correlation matrix
titanic_numeric_corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_07416_row0_col0, #T_07416_row1_col1, #T_07416_row2_col2, #T_07416_row3_col3, #T_07416_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_07416_row0_col1, #T_07416_row1_col0 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_07416_row0_col2, #T_07416_row2_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_07416_row0_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_07416_row0_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_07416_row1_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_07416_row1_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_07416_row1_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_07416_row2_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_07416_row2_col1, #T_07416_row2_col4, #T_07416_row4_col0, #T_07416_row4_col2, #T_07416_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_07416_row3_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_07416_row3_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_07416_row3_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_07416_row3_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_07416_row4_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_07416_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >who_TE</th>
#       <th class="col_heading level0 col1" >sex_TE</th>
#       <th class="col_heading level0 col2" >pclass</th>
#       <th class="col_heading level0 col3" >parch</th>
#       <th class="col_heading level0 col4" >age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07416_level0_row0" class="row_heading level0 row0" >who_TE</th>
#       <td id="T_07416_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_07416_row0_col1" class="data row0 col1" >0.940167</td>
#       <td id="T_07416_row0_col2" class="data row0 col2" >-0.120767</td>
#       <td id="T_07416_row0_col3" class="data row0 col3" >0.307829</td>
#       <td id="T_07416_row0_col4" class="data row0 col4" >-0.162058</td>
#     </tr>
#     <tr>
#       <th id="T_07416_level0_row1" class="row_heading level0 row1" >sex_TE</th>
#       <td id="T_07416_row1_col0" class="data row1 col0" >0.940167</td>
#       <td id="T_07416_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_07416_row1_col2" class="data row1 col2" >-0.131900</td>
#       <td id="T_07416_row1_col3" class="data row1 col3" >0.245489</td>
#       <td id="T_07416_row1_col4" class="data row1 col4" >-0.081163</td>
#     </tr>
#     <tr>
#       <th id="T_07416_level0_row2" class="row_heading level0 row2" >pclass</th>
#       <td id="T_07416_row2_col0" class="data row2 col0" >-0.120767</td>
#       <td id="T_07416_row2_col1" class="data row2 col1" >-0.131900</td>
#       <td id="T_07416_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_07416_row2_col3" class="data row2 col3" >0.018443</td>
#       <td id="T_07416_row2_col4" class="data row2 col4" >-0.339898</td>
#     </tr>
#     <tr>
#       <th id="T_07416_level0_row3" class="row_heading level0 row3" >parch</th>
#       <td id="T_07416_row3_col0" class="data row3 col0" >0.307829</td>
#       <td id="T_07416_row3_col1" class="data row3 col1" >0.245489</td>
#       <td id="T_07416_row3_col2" class="data row3 col2" >0.018443</td>
#       <td id="T_07416_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_07416_row3_col4" class="data row3 col4" >-0.172482</td>
#     </tr>
#     <tr>
#       <th id="T_07416_level0_row4" class="row_heading level0 row4" >age</th>
#       <td id="T_07416_row4_col0" class="data row4 col0" >-0.162058</td>
#       <td id="T_07416_row4_col1" class="data row4 col1" >-0.081163</td>
#       <td id="T_07416_row4_col2" class="data row4 col2" >-0.339898</td>
#       <td id="T_07416_row4_col3" class="data row4 col3" >-0.172482</td>
#       <td id="T_07416_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#calculate multicollinearity of numeric features
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(df):
    vif = pd.DataFrame()
    vif["features"] = df.columns
    vif["VIF Factor"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return vif

calc_vif(titanic_numeric)
# Out:
#   features  VIF Factor
# 0   who_TE   27.316460
# 1   sex_TE   28.379743
# 2   pclass    2.154487
# 3    parch    1.385424
# 4      age    2.670113

# %%
#remove transaction encoded features from numeric features
#<<<<<<<<<<<<<<< enter line of code here >>>>>>>>>>>>>>>>>>
#recalculate multicollinearity of numeric features
calc_vif(titanic_numeric)
# Out:
#   features  VIF Factor
# 0   pclass    2.016926
# 1    parch    1.171200
# 2      age    1.948926

# %%
#show remaining correlations with label
numeric_features_corr = titanic_numeric.corrwith(label)
numeric_features_corr
# Out:
# pclass   -0.338481
# parch     0.081629
# age      -0.064910
# dtype: float64
