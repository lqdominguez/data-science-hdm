# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#load planets dataset
planets_df = sns.load_dataset("planets")

#print shape of dataframe
print("Shape of data frame: ",planets_df.shape)
# Out:
# Shape of data frame:  (1035, 6)

# %%
#Show data frame
#<<<<<< add line of code here >>>>>>>
planets_df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
#show descriptive statistics of this dataset
#<<<<<< add line of code here >>>>>>>
print(planets_df.describe())

# print(planets_df.describe()['count','orbital_period'])


#How many missing values can be expected for "orbital_period" based on the shape information and the descriptive statistics ?
#<<<<<< add line of code here >>>>>>>
missing_orbital_period = planets_df['orbital_period'].isnull().sum()
print("Number of missing values in 'orbital_period': ", missing_orbital_period)
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000
# Descriptive statistics for 'orbital_period': count       992.000000
# mean       2002.917596
# std       26014.728304
# min           0.090706
# 25%           5.442540
# 50%          39.979500
# 75%         526.005000
# max      730000.000000
# Name: orbital_period, dtype: float64
# ...

# %%
#calculate and show correlation matrix for orbital_period, mass and distance
#<<<<<< add line of code here >>>>>>>
correlation_matrix = planets_df[['orbital_period', 'mass', 'distance']].corr()
#<<<<<< add line of code here >>>>>>>
print("Correlation matrix:\n", correlation_matrix)
# Out:
# Correlation matrix:
#                  orbital_period      mass  distance
# orbital_period        1.000000  0.173725 -0.034365
# mass                  0.173725  1.000000  0.274082
# distance             -0.034365  0.274082  1.000000

# %%
#draw Heatmap with correlations
#<<<<<< add line of code here >>>>>>>
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
correlation_matrix.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_97a4e_row0_col0, #T_97a4e_row1_col1, #T_97a4e_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_97a4e_row0_col1, #T_97a4e_row0_col2, #T_97a4e_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_97a4e_row1_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_97a4e_row1_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_97a4e_row2_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_97a4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97a4e_level0_col0" class="col_heading level0 col0" >orbital_period</th>
#       <th id="T_97a4e_level0_col1" class="col_heading level0 col1" >mass</th>
#       <th id="T_97a4e_level0_col2" class="col_heading level0 col2" >distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97a4e_level0_row0" class="row_heading level0 row0" >orbital_period</th>
# ...

# %%
#further investigate the correlation between the features in a scatter plot

#orbital period shall be plotted on x axis
#distance shall be plotted on y axis
#year shall be visualized through color 
#mass shall be represented by size ('s=')

#<<<<<< add line of code here >>>>>>>
scatter = planets_df.plot.scatter(x='orbital_period', y='distance', c='year', s=planets_df['mass'], cmap='viridis', linewidth=0.5)

# %%
#Analyze values for planet "mass" in a histogram with 15 bins
#<<<<<< add line of code here >>>>>>>
planets_df['mass'].plot.hist(bins=15,figsize=(10, 10))

#What is special about the shape of the distribution?
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Show combined boxplots for 'mass' and 'distance', but only for the first 500 rows of the dataset
#<<<<<< add line of code here >>>>>>>
planets_df.iloc[:500, [3,4]].plot.box(figsize=(10, 10))

#what is the problem with this boxplot?
# Out:
# <Axes: >

# %%
#Now show the same data in separate boxplots
#boxplot_mass
#<<<<<< add line of code here >>>>>>>
boxplot_mass = planets_df.iloc[:500, 3].plot.box(figsize=(5, 5), title='Boxplot of Mass')

# %%
#boxplot_distance
#<<<<<< add line of code here >>>>>>>
boxplot_distance = planets_df.iloc[:500, 4].plot.box(figsize=(5, 5), title='Boxplot of Distance')
