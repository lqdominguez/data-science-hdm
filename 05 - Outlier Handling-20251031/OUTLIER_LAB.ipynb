# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#load planets dataset
planets_df = sns.load_dataset("planets")

#print shape of dataframe
#<<<<<< add line of code here >>>>>>
print(planets_df.shape)
# Out:
# (1035, 6)

# %%
#Show data frame
#<<<<<< add line of code here >>>>>>
print(planets_df)
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %% [markdown]
# # Visual outlier detection

# %%
#Show combined PANDAS boxplots for 'orbital perios', mass' and 'distance'
#<<<<<< add line of code here >>>>>>
planets_df[['orbital_period', 'mass', 'distance']].plot.box()
# plt.show()
#what is the problem with this boxplot?
# Out:
# <Axes: >

# %%
#Create seperate boxplots for each of the three features
#create PANDAS boxplot for orbital period
#<<<<<< add line of code here >>>>>>

# %%
#boxplot for mass
#<<<<<< add line of code here >>>>>>

# %%
#boxplot for distance
#<<<<<< add line of code here >>>>>>

# %%
#Alternative: histograms
#show PANDAS histograms for all features
#<<<<<< add line of code here >>>>>>
#try to identify outliers from the histograms

# %% [markdown]
# # Univariate outlier detection

# %%
#Calculate and print difference between mean and median for feature "distance" in the planets data frame
#<<<<<< add line of code here >>>>>>
#<<<<<< add line of code here >>>>>>

#Calculate and print skew for feature "distance" in the planets dataframe
#<<<<<< add line of code here >>>>>>
#<<<<<< add line of code here >>>>>>
# Out:
# 208.81928217821786
# 7.362539120859176

# %%
#Univariate outlier detection based on descriptive statistics (three standard deviations)

#calculate a variable which stores the value of three standard deviations of feature "distance"
#<<<<<< add line of code here >>>>>>
#calculate a variable which stores the mean value of "distance"
#<<<<<< add line of code here >>>>>>

#calculate threshhold min value for inliers (mean-three standard deviations)
#<<<<<< add line of code here >>>>>>
#calculate threshhold max value for inliers (mean-three standard deviations)
#<<<<<< add line of code here >>>>>>
#print thresshold min and max values
print("mean: ",mean, "lower boundary inlier: ",inlier_low, "upper boundary inlier",inlier_high,"\n")

#loop alle values in feature "distance", compare vales with thressholds and print if value is outlier
#<<<<<< add line of code here >>>>>>
#<<<<<< add line of code here >>>>>>
#<<<<<< add line of code here >>>>>>
# Out:
# mean:  264.06928217821786 lower boundary inlier:  -1935.2801966431086 upper boundary inlier 2463.4187609995442
#
# 2700.0  is a potential outlier
# 3600.0  is a potential outlier
# 2800.0  is a potential outlier
# 7720.0  is a potential outlier
# 7560.0  is a potential outlier
# 2570.0  is a potential outlier
# 4080.0  is a potential outlier
# 4080.0  is a potential outlier
# 4970.0  is a potential outlier
# 2500.0  is a potential outlier
# 8500.0  is a potential outlier
# 8500.0  is a potential outlier
# 3200.0  is a potential outlier
