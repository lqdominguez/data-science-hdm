# %% [markdown]
# # Modelling optimization

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

import time

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Load data

# %%
# Load training and testing datasets with ; separator
train_set = pd.read_csv('BikeRentalDaily_train_prepared.csv', sep=',')
val_set = pd.read_csv('BikeRentalDaily_val_prepared.csv', sep=',')
test_set = pd.read_csv('BikeRentalDaily_test_prepared.csv', sep=',')

print("Training Data Shape:", train_set.shape)
print("Validation Data Shape:", val_set.shape)
print("Testing Data Shape:", test_set.shape)

train_set.head()
# Out:
# Training Data Shape: (480, 21)
# Validation Data Shape: (120, 21)
# Testing Data Shape: (132, 21)
#    instant  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0      207     3.0   0     7        0        2           1           1
# 1       71     1.0   0     3        0        6           0           1
# 2       60     1.0   0     3        0        2           1           1
# 3      477     2.0   1     4        0        6           0           1
# 4       44     1.0   0     2        0        6           0           1
#
#       temp        hum  ...  leaflets  price reduction   cnt  day_of_month  \
# 0  30.8667  44.981347  ...       692                0  4590            26
# 1  13.1667  51.832120  ...       580                0  2132            12
# 2  10.6667  44.237895  ...       971                0  1851             1
# 3  22.8000  63.090839  ...       524                0  6624            21
# 4  12.6609  34.346143  ...       686                1  1589            13
#
#      season_sin    season_cos  mnth_sin      mnth_cos  weekday_sin  \
# 0 -1.000000e+00 -1.836970e-16 -0.500000 -8.660254e-01     0.974928
# 1  1.000000e+00  6.123234e-17  1.000000  6.123234e-17    -0.781831
# 2  1.000000e+00  6.123234e-17  1.000000  6.123234e-17     0.974928
# 3  1.224647e-16 -1.000000e+00  0.866025 -5.000000e-01    -0.781831
# 4  1.000000e+00  6.123234e-17  0.866025  5.000000e-01    -0.781831
#
#    weekday_cos
# 0    -0.222521
# 1     0.623490
# 2    -0.222521
# 3     0.623490
# 4     0.623490
#
# [5 rows x 21 columns]

# %%
# Separate Features (X) and Target (y) for all three sets
# Training Set (used to fit the model)
X_train = train_set.drop(columns=['cnt'])
y_train = train_set['cnt']

# Validation Set (used to evaluate performance during training)
X_val = val_set.drop(columns=['cnt'])
y_val = val_set['cnt']

# Test Set
X_test = test_set.drop(columns=['cnt'])
y_test = test_set['cnt']

# %% [markdown]
# # Auxiliar functions

# %%
# Initialize our master list
model_performance_list = []

def record_performance(model_name, model, X_train, y_train, X_val, y_val, train_time, notes="Default", step="Baseline"):
    """
    Records results. train_time must be passed as a parameter 
    representing the duration of the training task.
    """
    # Generate predictions
    train_preds = model.predict(X_train)
    val_preds = model.predict(X_val)
    
    # Calculate metrics
    perf = {
        "Model": model_name,
        "Step": step,
        "Train MAE": mean_absolute_error(y_train, train_preds),
        "Val MAE": mean_absolute_error(y_val, val_preds),
        "Train R2": r2_score(y_train, train_preds),
        "Val R2": r2_score(y_val, val_preds),
        "Train Time (s)": round(train_time, 4), # Recorded from the parameter
        "Notes": notes
    }
    
    model_performance_list.append(perf)
    return pd.DataFrame(model_performance_list)

# %%
def get_performance_summary(results_list=None, sort_by="Val MAE", ascending=True):
    """
    Returns a formatted DataFrame. 
    'results_list': defaults to the global list if None.
    'sort_by': the column name to sort by.
    'ascending': True for MAE (lower is better), False for R2 (higher is better).
    """
    if results_list is None:
        results_list = model_performance_list
        
    df = pd.DataFrame(results_list)
    
    # Check if the requested column exists to avoid errors
    if sort_by in df.columns:
        return df.sort_values(by=sort_by, ascending=ascending)
    else:
        print(f"Warning: {sort_by} not found. Returning unsorted.")
        return df

# %%
def show_summary_graph(df, steps_to_show=None):
    """
    Generates performance graphs. 
    'steps_to_show' can be a string or a list of strings (e.g., ["Baseline", "Optimized"]).
    If None, it shows all steps.
    """
    # 1. Filter the dataframe if specific steps are requested
    df_to_plot = df.copy()
    if steps_to_show is not None:
        # If a single string is passed, convert it to a list
        if isinstance(steps_to_show, str):
            steps_to_show = [steps_to_show]
        # Filter rows where 'Step' is in the provided list
        df_to_plot = df_to_plot[df_to_plot['Step'].isin(steps_to_show)]

    if df_to_plot.empty:
        print("No data found for the selected steps.")
        return

    # 2. Prepare Labels and Sort
    # We combine Model and Step for a clear Y-axis label
    df_to_plot['Label'] = df_to_plot['Model'] + " (" + df_to_plot['Step'] + ")"
    
    # Sorting by Val MAE usually makes the comparison more intuitive
    df_sorted = df_to_plot.sort_values('Model', ascending=True)

    # --- PLOT 1: Mean Absolute Error (MAE) ---
    plt.figure(figsize=(12, 10))
    mae_df = df_sorted.melt(id_vars='Label', value_vars=['Train MAE', 'Val MAE'], 
                            var_name='Dataset', value_name='MAE')

    sns.barplot(data=mae_df, y='Label', x='MAE', hue='Dataset', palette='viridis')
    plt.title('Mean Absolute Error (MAE): Lower is Better', fontsize=14, fontweight='bold')
    plt.xlabel('MAE (Units: Bike Count)', fontsize=12)
    plt.ylabel('Model Configuration', fontsize=12)
    plt.grid(axis='x', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

    # --- PLOT 2: R-Squared (R2) ---
    plt.figure(figsize=(12, 10))
    r2_df = df_sorted.melt(id_vars='Label', value_vars=['Train R2', 'Val R2'], 
                           var_name='Dataset', value_name='R2')

    sns.barplot(data=r2_df, y='Label', x='R2', hue='Dataset', palette='magma')
    plt.title('R2-Score (R2): Higher is Better', fontsize=14, fontweight='bold')
    plt.xlabel('R2 Score (Variance Explained)', fontsize=12)
    plt.ylabel('Model Configuration', fontsize=12)
    plt.xlim(-1, 1) 
    plt.grid(axis='x', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Baseline models

# %%
models = [
    ("Linear Regression", LinearRegression()),
    ("Decision Tree", DecisionTreeRegressor(random_state=42)),
    ("SVR", SVR()),
    ("k-NN", KNeighborsRegressor()),
    ("Random Forest", RandomForestRegressor(random_state=42)),
    ("XGBoost", XGBRegressor(random_state=42)),
    ("LightGBM", LGBMRegressor(random_state=42)),
    ("CatBoost", CatBoostRegressor(random_state=42, verbose=0)),
]

# %%
for name, model_obj in models:
    print(f"Processing: {name}...")
    
    # Training
    start = time.time()
    model_obj.fit(X_train, y_train)
    end = time.time()
    duration = end - start
    
    # Record results
    record_performance(
        model_name=name, 
        model=model_obj, 
        X_train=X_train, 
        y_train=y_train, 
        X_val=X_val, 
        y_val=y_val, 
        train_time=duration, 
        notes="Default parameters, no scaling",
        step="Baseline",
    )
# Out:
# Processing: Linear Regression...
# Processing: Decision Tree...
# Processing: SVR...
# Processing: k-NN...
# Processing: Random Forest...
# Processing: XGBoost...
# Processing: LightGBM...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000088 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 915
# [LightGBM] [Info] Number of data points in the train set: 480, number of used features: 19
# [LightGBM] [Info] Start training from score 4664.922917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Processing: CatBoost...

# %% [markdown]
# ## Show baseline results

# %%
# View results
results = get_performance_summary(sort_by="Val MAE")
display(results)
# Out:
#                Model      Step    Train MAE      Val MAE  Train R2    Val R2  \
# 7           CatBoost  Baseline   123.638364  1016.564289  0.997751  0.296183
# 6           LightGBM  Baseline   437.941413  1200.831472  0.718793  0.250635
# 4      Random Forest  Baseline   307.633542  1304.098167  0.883017 -0.044472
# 0  Linear Regression  Baseline   859.281939  1341.873287  0.353380  0.221641
# 1      Decision Tree  Baseline     0.000000  1454.975000  1.000000 -0.805838
# 5            XGBoost  Baseline     5.945889  1459.346924  0.999993 -0.573390
# 3               k-NN  Baseline   773.838333  1461.456667  0.487123  0.091054
# 2                SVR  Baseline  1716.059980  1976.854782  0.004826 -0.002225
#
#    Train Time (s)                           Notes
# 7          1.3035  Default parameters, no scaling
# 6          0.0258  Default parameters, no scaling
# 4          0.2943  Default parameters, no scaling
# 0          0.0066  Default parameters, no scaling
# 1          0.0097  Default parameters, no scaling
# 5          0.0769  Default parameters, no scaling
# 3          0.0000  Default parameters, no scaling
# 2          0.0125  Default parameters, no scaling

# %%
# Show results in graph
show_summary_graph(results)

# %% [markdown]
# ## Partial conclusions from baseline results

# %% [markdown]
# - Decision Tree and XGBoost are highly overfitted models. Low train MAE and high validation MAE with negative validation R2-scores.
# - All the models suffer of overfitting.
# - Catboost has the best performance in terms of MAE and R2-score. However the results are still really bad.
#
# Some explanations can be related with:
# - The algorithms were trained without constraints like max_depth in the case of Decision Trees, so they try to fit every example in the training set.
# - The features aren't standardized and that might affect models that rely on distances (like SVR and k-NN).

# %% [markdown]
# # Baseline models basic optimization

# %% [markdown]
# ## Constraint trees depths

# %% [markdown]
# ### Decission Tree

# %%
# Define max_depth and min_samples_leaf
pruned_dt = DecisionTreeRegressor(
    max_depth=10, 
    min_samples_leaf=10, 
    random_state=42
)

# Time the training
start = time.time()
pruned_dt.fit(X_train, y_train)
duration = time.time() - start

# Record the new improved result
record_performance(
    "Decision Tree", 
    pruned_dt, 
    X_train, y_train, 
    X_val, y_val, 
    train_time=duration, 
    notes="Stabilized: Pruned",
    step="Stabilized",
)
# Out:
#                Model        Step    Train MAE      Val MAE  Train R2  \
# 0  Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 1      Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 2                SVR    Baseline  1716.059980  1976.854782  0.004826
# 3               k-NN    Baseline   773.838333  1461.456667  0.487123
# 4      Random Forest    Baseline   307.633542  1304.098167  0.883017
# 5            XGBoost    Baseline     5.945889  1459.346924  0.999993
# 6           LightGBM    Baseline   437.941413  1200.831472  0.718793
# 7           CatBoost    Baseline   123.638364  1016.564289  0.997751
# 8      Decision Tree  Stabilized   707.592570  1270.124265  0.470122
#
#      Val R2  Train Time (s)                           Notes
# 0  0.221641          0.0066  Default parameters, no scaling
# 1 -0.805838          0.0097  Default parameters, no scaling
# 2 -0.002225          0.0125  Default parameters, no scaling
# 3  0.091054          0.0000  Default parameters, no scaling
# 4 -0.044472          0.2943  Default parameters, no scaling
# 5 -0.573390          0.0769  Default parameters, no scaling
# 6  0.250635          0.0258  Default parameters, no scaling
# 7  0.296183          1.3035  Default parameters, no scaling
# 8  0.204066          0.0053              Stabilized: Pruned

# %% [markdown]
# ### Random Forest

# %%
# Limit depth and stablish min samples per leaf for generalization
pruned_rf = RandomForestRegressor(
    max_depth=12,          # Stop trees from getting too specific
    min_samples_leaf=5,    # Each leaf must represent at least 5 bike rentals
    random_state=42
)

start = time.time()
pruned_rf.fit(X_train, y_train)
duration = time.time() - start

record_performance("Random Forest", pruned_rf, X_train, y_train, X_val, y_val, duration, notes="Stabilized: Pruned", step="Stabilized")
# Out:
#                Model        Step    Train MAE      Val MAE  Train R2  \
# 0  Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 1      Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 2                SVR    Baseline  1716.059980  1976.854782  0.004826
# 3               k-NN    Baseline   773.838333  1461.456667  0.487123
# 4      Random Forest    Baseline   307.633542  1304.098167  0.883017
# 5            XGBoost    Baseline     5.945889  1459.346924  0.999993
# 6           LightGBM    Baseline   437.941413  1200.831472  0.718793
# 7           CatBoost    Baseline   123.638364  1016.564289  0.997751
# 8      Decision Tree  Stabilized   707.592570  1270.124265  0.470122
# 9      Random Forest  Stabilized   608.068712  1100.454092  0.547521
#
#      Val R2  Train Time (s)                           Notes
# 0  0.221641          0.0066  Default parameters, no scaling
# 1 -0.805838          0.0097  Default parameters, no scaling
# 2 -0.002225          0.0125  Default parameters, no scaling
# 3  0.091054          0.0000  Default parameters, no scaling
# 4 -0.044472          0.2943  Default parameters, no scaling
# 5 -0.573390          0.0769  Default parameters, no scaling
# 6  0.250635          0.0258  Default parameters, no scaling
# 7  0.296183          1.3035  Default parameters, no scaling
# 8  0.204066          0.0053              Stabilized: Pruned
# 9  0.285295          0.2145              Stabilized: Pruned

# %% [markdown]
# ### XGBoost

# %%
# Stabilization for XGBoost
pruned_xgb = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,    # Slow down the learning (default is 0.3)
    max_depth=5,           # Shorter trees are less likely to overfit
    subsample=0.8,         # Use only 80% of data per tree (adds randomness)
    colsample_bytree=0.8,  # Use only 80% of features per tree
    random_state=42
)

start = time.time()
pruned_xgb.fit(X_train, y_train)
duration = time.time() - start

record_performance("XGBoost", pruned_xgb, X_train, y_train, X_val, y_val, duration, notes="Stabilized: Pruned and randomized", step="Stabilized")
# Out:
#                 Model        Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 2                 SVR    Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN    Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest    Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost    Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM    Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost    Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree  Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest  Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost  Stabilized    37.347328  1203.684814  0.999793
#
#       Val R2  Train Time (s)                              Notes
# 0   0.221641          0.0066     Default parameters, no scaling
# 1  -0.805838          0.0097     Default parameters, no scaling
# 2  -0.002225          0.0125     Default parameters, no scaling
# 3   0.091054          0.0000     Default parameters, no scaling
# 4  -0.044472          0.2943     Default parameters, no scaling
# 5  -0.573390          0.0769     Default parameters, no scaling
# 6   0.250635          0.0258     Default parameters, no scaling
# 7   0.296183          1.3035     Default parameters, no scaling
# 8   0.204066          0.0053                 Stabilized: Pruned
# 9   0.285295          0.2145                 Stabilized: Pruned
# 10  0.123445          0.2482  Stabilized: Pruned and randomized

# %% [markdown]
# ### LightGBM

# %%
improved_lgbm = LGBMRegressor(
    n_estimators=500,
    learning_rate=0.05,
    num_leaves=31,        # Main parameter for LightGBM complexity
    max_depth=7,          # Limit depth to prevent overfitting
    random_state=42,
    verbosity=-1
)

start = time.time()
improved_lgbm.fit(X_train, y_train)
duration = time.time() - start

record_performance("LightGBM", improved_lgbm, X_train, y_train, X_val, y_val, duration, notes="Stabilized: Throttled", step="Stabilized")
# Out:
#                 Model        Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 2                 SVR    Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN    Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest    Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost    Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM    Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost    Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree  Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest  Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost  Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM  Stabilized   368.857442  1357.610999  0.883220
#
#       Val R2  Train Time (s)                              Notes
# 0   0.221641          0.0066     Default parameters, no scaling
# 1  -0.805838          0.0097     Default parameters, no scaling
# 2  -0.002225          0.0125     Default parameters, no scaling
# 3   0.091054          0.0000     Default parameters, no scaling
# 4  -0.044472          0.2943     Default parameters, no scaling
# 5  -0.573390          0.0769     Default parameters, no scaling
# 6   0.250635          0.0258     Default parameters, no scaling
# 7   0.296183          1.3035     Default parameters, no scaling
# 8   0.204066          0.0053                 Stabilized: Pruned
# 9   0.285295          0.2145                 Stabilized: Pruned
# 10  0.123445          0.2482  Stabilized: Pruned and randomized
# 11  0.174405          0.0755              Stabilized: Throttled

# %% [markdown]
# ### CatBoost

# %%
improved_cat = CatBoostRegressor(
    n_estimators=500,
    learning_rate=0.05,
    depth=8,
    random_state=42,
    verbose=0
)

start = time.time()
improved_cat.fit(X_train, y_train)
duration = time.time() - start

record_performance("CatBoost", improved_cat, X_train, y_train, X_val, y_val, duration, notes="Stabilized: Regularized", step="Stabilized")
# Out:
#                 Model        Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 2                 SVR    Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN    Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest    Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost    Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM    Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost    Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree  Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest  Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost  Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM  Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost  Stabilized   109.159958  1000.621020  0.998198
#
#       Val R2  Train Time (s)                              Notes
# 0   0.221641          0.0066     Default parameters, no scaling
# 1  -0.805838          0.0097     Default parameters, no scaling
# 2  -0.002225          0.0125     Default parameters, no scaling
# 3   0.091054          0.0000     Default parameters, no scaling
# 4  -0.044472          0.2943     Default parameters, no scaling
# 5  -0.573390          0.0769     Default parameters, no scaling
# 6   0.250635          0.0258     Default parameters, no scaling
# 7   0.296183          1.3035     Default parameters, no scaling
# 8   0.204066          0.0053                 Stabilized: Pruned
# 9   0.285295          0.2145                 Stabilized: Pruned
# 10  0.123445          0.2482  Stabilized: Pruned and randomized
# 11  0.174405          0.0755              Stabilized: Throttled
# 12  0.314068          1.3817            Stabilized: Regularized

# %% [markdown]
# ## Standarization for distance based methods

# %%
# Initialize the Scaler
std_scaler = StandardScaler()

# Fit and Transform Training data
X_train_scaled = std_scaler.fit_transform(X_train)
print(X_train_scaled.shape)

# Transform Validation data
X_val_scaled = std_scaler.transform(X_val)


# Transform Test data
X_test_scaled = std_scaler.transform(X_test)
print(X_test_scaled.shape)
# Out:
# (480, 20)
# (132, 20)

# %% [markdown]
# ### Linear Regression

# %%
# We use the SCALED data here so we can compare feature importance later
improved_lr = LinearRegression()

start = time.time()
improved_lr.fit(X_train_scaled, y_train)
duration = time.time() - start

record_performance("Linear Regression", improved_lr, X_train_scaled, y_train, X_val_scaled, y_val, duration, notes="Stabilized: Scaled", step="Stabilized")
# Out:
#                 Model        Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 2                 SVR    Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN    Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest    Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost    Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM    Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost    Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree  Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest  Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost  Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM  Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost  Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression  Stabilized   859.281939  1341.873287  0.353380
#
#       Val R2  Train Time (s)                              Notes
# 0   0.221641          0.0066     Default parameters, no scaling
# 1  -0.805838          0.0097     Default parameters, no scaling
# 2  -0.002225          0.0125     Default parameters, no scaling
# 3   0.091054          0.0000     Default parameters, no scaling
# 4  -0.044472          0.2943     Default parameters, no scaling
# 5  -0.573390          0.0769     Default parameters, no scaling
# 6   0.250635          0.0258     Default parameters, no scaling
# 7   0.296183          1.3035     Default parameters, no scaling
# 8   0.204066          0.0053                 Stabilized: Pruned
# 9   0.285295          0.2145                 Stabilized: Pruned
# 10  0.123445          0.2482  Stabilized: Pruned and randomized
# 11  0.174405          0.0755              Stabilized: Throttled
# 12  0.314068          1.3817            Stabilized: Regularized
# 13  0.221641          0.0000                 Stabilized: Scaled

# %% [markdown]
# ### k-NN

# %%
# Increasing neighbors usually helps smooth out predictions
improved_knn = KNeighborsRegressor(n_neighbors=7, weights='uniform')

start = time.time()
improved_knn.fit(X_train_scaled, y_train) # Use SCALED data
duration = time.time() - start

record_performance("k-NN", improved_knn, X_train_scaled, y_train, X_val_scaled, y_val, duration, notes="Stabilized: Scaled + k=7", step="Stabilized")
# Out:
#                 Model        Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 2                 SVR    Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN    Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest    Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost    Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM    Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost    Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree  Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest  Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost  Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM  Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost  Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression  Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN  Stabilized   795.725893  1237.861905  0.461550
#
#       Val R2  Train Time (s)                              Notes
# 0   0.221641          0.0066     Default parameters, no scaling
# 1  -0.805838          0.0097     Default parameters, no scaling
# 2  -0.002225          0.0125     Default parameters, no scaling
# 3   0.091054          0.0000     Default parameters, no scaling
# 4  -0.044472          0.2943     Default parameters, no scaling
# 5  -0.573390          0.0769     Default parameters, no scaling
# 6   0.250635          0.0258     Default parameters, no scaling
# 7   0.296183          1.3035     Default parameters, no scaling
# 8   0.204066          0.0053                 Stabilized: Pruned
# 9   0.285295          0.2145                 Stabilized: Pruned
# 10  0.123445          0.2482  Stabilized: Pruned and randomized
# 11  0.174405          0.0755              Stabilized: Throttled
# 12  0.314068          1.3817            Stabilized: Regularized
# 13  0.221641          0.0000                 Stabilized: Scaled
# 14  0.367226          0.0015           Stabilized: Scaled + k=7

# %% [markdown]
# ### Support Vector Regressor

# %%
# SVR is extremely sensitive to scaling
improved_svr = SVR(C=1000, epsilon=10)

start = time.time()
improved_svr.fit(X_train_scaled, y_train) # Use SCALED data
duration = time.time() - start

record_performance("SVR", improved_svr, X_train_scaled, y_train, X_val_scaled, y_val, duration, notes="Stabilized: Scaled + C=1000", step="Stabilized")
# Out:
#                 Model        Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 2                 SVR    Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN    Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest    Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost    Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM    Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost    Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree  Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest  Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost  Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM  Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost  Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression  Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN  Stabilized   795.725893  1237.861905  0.461550
# 15                SVR  Stabilized   464.347225   984.390504  0.363713
#
#       Val R2  Train Time (s)                              Notes
# 0   0.221641          0.0066     Default parameters, no scaling
# 1  -0.805838          0.0097     Default parameters, no scaling
# 2  -0.002225          0.0125     Default parameters, no scaling
# 3   0.091054          0.0000     Default parameters, no scaling
# 4  -0.044472          0.2943     Default parameters, no scaling
# 5  -0.573390          0.0769     Default parameters, no scaling
# 6   0.250635          0.0258     Default parameters, no scaling
# 7   0.296183          1.3035     Default parameters, no scaling
# 8   0.204066          0.0053                 Stabilized: Pruned
# 9   0.285295          0.2145                 Stabilized: Pruned
# 10  0.123445          0.2482  Stabilized: Pruned and randomized
# 11  0.174405          0.0755              Stabilized: Throttled
# 12  0.314068          1.3817            Stabilized: Regularized
# 13  0.221641          0.0000                 Stabilized: Scaled
# 14  0.367226          0.0015           Stabilized: Scaled + k=7
# 15  0.264364          0.0159        Stabilized: Scaled + C=1000

# %% [markdown]
# # Show results

# %%
# View results
results = get_performance_summary(sort_by="Model")
display(results)
# Out:
#                 Model        Step    Train MAE      Val MAE  Train R2  \
# 7            CatBoost    Baseline   123.638364  1016.564289  0.997751
# 12           CatBoost  Stabilized   109.159958  1000.621020  0.998198
# 1       Decision Tree    Baseline     0.000000  1454.975000  1.000000
# 8       Decision Tree  Stabilized   707.592570  1270.124265  0.470122
# 6            LightGBM    Baseline   437.941413  1200.831472  0.718793
# 11           LightGBM  Stabilized   368.857442  1357.610999  0.883220
# 0   Linear Regression    Baseline   859.281939  1341.873287  0.353380
# 13  Linear Regression  Stabilized   859.281939  1341.873287  0.353380
# 4       Random Forest    Baseline   307.633542  1304.098167  0.883017
# 9       Random Forest  Stabilized   608.068712  1100.454092  0.547521
# 2                 SVR    Baseline  1716.059980  1976.854782  0.004826
# 15                SVR  Stabilized   464.347225   984.390504  0.363713
# 5             XGBoost    Baseline     5.945889  1459.346924  0.999993
# 10            XGBoost  Stabilized    37.347328  1203.684814  0.999793
# 3                k-NN    Baseline   773.838333  1461.456667  0.487123
# 14               k-NN  Stabilized   795.725893  1237.861905  0.461550
#
#       Val R2  Train Time (s)                              Notes
# 7   0.296183          1.3035     Default parameters, no scaling
# 12  0.314068          1.3817            Stabilized: Regularized
# 1  -0.805838          0.0097     Default parameters, no scaling
# 8   0.204066          0.0053                 Stabilized: Pruned
# 6   0.250635          0.0258     Default parameters, no scaling
# 11  0.174405          0.0755              Stabilized: Throttled
# 0   0.221641          0.0066     Default parameters, no scaling
# 13  0.221641          0.0000                 Stabilized: Scaled
# 4  -0.044472          0.2943     Default parameters, no scaling
# 9   0.285295          0.2145                 Stabilized: Pruned
# 2  -0.002225          0.0125     Default parameters, no scaling
# 15  0.264364          0.0159        Stabilized: Scaled + C=1000
# 5  -0.573390          0.0769     Default parameters, no scaling
# 10  0.123445          0.2482  Stabilized: Pruned and randomized
# 3   0.091054          0.0000     Default parameters, no scaling
# 14  0.367226          0.0015           Stabilized: Scaled + k=7

# %%
# Show results in graph
show_summary_graph(results)

# %% [markdown]
# ## Partial conclusions from basic optimization

# %% [markdown]
# - SVR from the worst result became in the best one in terms of MAE. The scaling and some basic parameter optimization produced a great change in the performance. The differences of MAE in training and validation were also reduced probing best generalization
# - XGBoost show really low MAE in training, showing a high overfitting
# - Random Forest ist the most robust model with the lest difference in the MAE duriong training and during validation

# %% [markdown]
# # Feature selection using correlation and colinearity

# %% [markdown]
# ### Based on correlation

# %%
#caluclate correlation of numeric features with label
target_corr = X_train.corrwith(y_train).abs().sort_values(ascending=False)
target_corr
# Out:
# instant            0.416765
# temp               0.384511
# yr                 0.370203
# season_sin         0.345675
# mnth_cos           0.280188
# mnth_sin           0.241165
# season             0.232309
# weathersit         0.210954
# mnth               0.194216
# windspeed          0.152504
# weekday            0.089427
# hum                0.083648
# weekday_sin        0.082733
# leaflets           0.073172
# season_cos         0.061271
# holiday            0.057434
# workingday         0.056789
# price reduction    0.037477
# weekday_cos        0.031024
# day_of_month       0.022134
# dtype: float64

# %%
# Filter out low values
low_relevance = target_corr[target_corr < 0.05]

# 2. Delete them from your Training and Validation sets
low_relevance_features = low_relevance.index.tolist()
X_train_reduced = X_train.drop(columns=low_relevance_features)
X_val_reduced = X_val.drop(columns=low_relevance_features)

print(f"Removed low-relevance features: {low_relevance_features}")
# Out:
# Removed low-relevance features: ['price reduction', 'weekday_cos', 'day_of_month']

# %% [markdown]
# ### Detect Collinearity

# %%
# 1. Visualization: Heatmap of the Feature-to-Feature relationships
plt.figure(figsize=(12, 10))
# We use the actual X_train_reduced features here
feature_corr = X_train_reduced.corr()
mask = np.triu(np.ones_like(feature_corr, dtype=bool)) # Hide the duplicate half

sns.heatmap(feature_corr, mask=mask, annot=True, fmt=".2f", cmap='RdBu_r', center=0)
plt.title("Collinearity Matrix (Feature vs Feature)")
plt.show()

# %%
threshold = 0.5

#apply a mask to highlight colinearity values > 0.5
feature_corr_strong = (abs(feature_corr) > threshold)*1
# Displaying correlations as a heatmap / correlation matrix
feature_corr_strong.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_1f935_row0_col0, #T_1f935_row0_col2, #T_1f935_row0_col3, #T_1f935_row1_col1, #T_1f935_row1_col3, #T_1f935_row1_col12, #T_1f935_row1_col13, #T_1f935_row1_col14, #T_1f935_row2_col0, #T_1f935_row2_col2, #T_1f935_row3_col0, #T_1f935_row3_col1, #T_1f935_row3_col3, #T_1f935_row3_col12, #T_1f935_row3_col13, #T_1f935_row3_col14, #T_1f935_row4_col4, #T_1f935_row5_col5, #T_1f935_row5_col6, #T_1f935_row5_col16, #T_1f935_row6_col5, #T_1f935_row6_col6, #T_1f935_row6_col16, #T_1f935_row7_col7, #T_1f935_row7_col9, #T_1f935_row8_col8, #T_1f935_row8_col12, #T_1f935_row8_col15, #T_1f935_row9_col7, #T_1f935_row9_col9, #T_1f935_row10_col10, #T_1f935_row11_col11, #T_1f935_row12_col1, #T_1f935_row12_col3, #T_1f935_row12_col8, #T_1f935_row12_col12, #T_1f935_row12_col14, #T_1f935_row12_col15, #T_1f935_row13_col1, #T_1f935_row13_col3, #T_1f935_row13_col13, #T_1f935_row13_col14, #T_1f935_row13_col15, #T_1f935_row14_col1, #T_1f935_row14_col3, #T_1f935_row14_col12, #T_1f935_row14_col13, #T_1f935_row14_col14, #T_1f935_row15_col8, #T_1f935_row15_col12, #T_1f935_row15_col13, #T_1f935_row15_col15, #T_1f935_row16_col5, #T_1f935_row16_col6, #T_1f935_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1f935_row0_col1, #T_1f935_row0_col4, #T_1f935_row0_col5, #T_1f935_row0_col6, #T_1f935_row0_col7, #T_1f935_row0_col8, #T_1f935_row0_col9, #T_1f935_row0_col10, #T_1f935_row0_col11, #T_1f935_row0_col12, #T_1f935_row0_col13, #T_1f935_row0_col14, #T_1f935_row0_col15, #T_1f935_row0_col16, #T_1f935_row1_col0, #T_1f935_row1_col2, #T_1f935_row1_col4, #T_1f935_row1_col5, #T_1f935_row1_col6, #T_1f935_row1_col7, #T_1f935_row1_col8, #T_1f935_row1_col9, #T_1f935_row1_col10, #T_1f935_row1_col11, #T_1f935_row1_col15, #T_1f935_row1_col16, #T_1f935_row2_col1, #T_1f935_row2_col3, #T_1f935_row2_col4, #T_1f935_row
#T_1f935_row10_col7, #T_1f935_row10_col8, #T_1f935_row10_col9, #T_1f935_row10_col11, #T_1f935_row10_col12, #T_1f935_row10_col13, #T_1f935_row10_col14, #T_1f935_row10_col15, #T_1f935_row10_col16, #T_1f935_row11_col0, #T_1f935_row11_col1, #T_1f935_row11_col2, #T_1f935_row11_col3, #T_1f935_row11_col4, #T_1f935_row11_col5, #T_1f935_row11_col6, #T_1f935_row11_col7, #T_1f935_row11_col8, #T_1f935_row11_col9, #T_1f935_row11_col10, #T_1f935_row11_col12, #T_1f935_row11_col13, #T_1f935_row11_col14, #T_1f935_row11_col15, #T_1f935_row11_col16, #T_1f935_row12_col0, #T_1f935_row12_col2, #T_1f935_row12_col4, #T_1f935_row12_col5, #T_1f935_row12_col6, #T_1f935_row12_col7, #T_1f935_row12_col9, #T_1f935_row12_col10, #T_1f935_row12_col11, #T_1f935_row12_col13, #T_1f935_row12_col16, #T_1f935_row13_col0, #T_1f935_row13_col2, #T_1f935_row13_col4, #T_1f935_row13_col5, #T_1f935_row13_col6, #T_1f935_row13_col7, #T_1f935_row13_col8, #T_1f935_row13_col9, #T_1f935_row13_col10, #T_1f935_row13_col11, #T_1f935_ ...
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1f935">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f935_level0_col0" class="col_heading level0 col0" >instant</th>
#       <th id="T_1f935_level0_col1" class="col_heading level0 col1" >season</th>
#       <th id="T_1f935_level0_col2" class="col_heading level0 col2" >yr</th>
#       <th id="T_1f935_level0_col3" class="col_heading level0 col3" >mnth</th>
#       <th id="T_1f935_level0_col4" class="col_heading level0 col4" >holiday</th>
#       <th id="T_1f935_level0_col5" class="col_heading level0 col5" >weekday</th>
#       <th id="T_1f935_level0_col6" class="col_heading level0 col6" >workingday</th>
#       <th id="T_1f935_level0_col7" class="col_heading level0 col7" >weathersit</th>
#       <th id="T_1f935_level0_col8" class="col_heading level0 col8" >temp</th>
#       <th id="T_1f935_level0_col9" class="col_heading level0 col9" >hum</th>
#       <th id="T_1f935_level0_col10" class="col_heading level0 col10" >windspeed</th>
#       <th id="T_1f935_level0_col11" class="col_heading level0 col11" >leaflets</th>
#       <th id="T_1f935_level0_col12" class="col_heading level0 col12" >season_sin</th>
#       <th id="T_1f935_level0_col13" class="col_heading level0 col13" >season_cos</th>
#       <th id="T_1f935_level0_col14" class="col_heading level0 col14" >mnth_sin</th>
#       <th id="T_1f935_level0_col15" class="col_heading level0 col15" >mnth_cos</th>
#       <th id="T_1f935_level0_col16" class="col_heading level0 col16" >weekday_sin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f935_level0_row0" class="row_heading level0 row0" >instant</th>
#       <td id="T_1f935_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1f935_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_1f935_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_1f935_row0_col3" class="data row0 col3"

# %% [markdown]
# ## Variance Inflation Factor

# %%
# calculate multicollinearity of numeric features
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(df):
    vif = pd.DataFrame()
    vif["features"] = df.columns
    vif["VIF Factor"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return vif.sort_values(by="VIF Factor", ascending=False)
    
calc_vif(X_train_reduced)
# Out:
#        features   VIF Factor
# 0       instant  2233.921901
# 2            yr   859.215441
# 3          mnth   626.608801
# 5       weekday    46.290029
# 8          temp    43.364949
# 1        season    43.355255
# 9           hum    24.302555
# 11     leaflets    19.377737
# 7    weathersit    15.473798
# 15     mnth_cos     7.973985
# 10    windspeed     7.744914
# 6    workingday     7.306306
# 13   season_cos     6.934726
# 12   season_sin     6.790517
# 16  weekday_sin     6.414341
# 14     mnth_sin     6.125054
# 4       holiday     1.522988

# %%
X_vif_recursive = X_train_reduced.copy()
vif_dropped_list = []
max_vif_threshold = 10.0

while True:
    # Get current scores
    vif_df = calc_vif(X_vif_recursive)
    
    # Find the highest VIF value and the feature name
    current_max_vif = vif_df['VIF Factor'].max()
    feature_to_remove = vif_df.sort_values('VIF Factor', ascending=False)['features'].iloc[0]
    
    if current_max_vif > max_vif_threshold:
        print(f"Removing '{feature_to_remove}' with VIF: {current_max_vif:.2f}")
        
        # 3. Drop from the working dataframe
        X_vif_recursive = X_vif_recursive.drop(columns=[feature_to_remove])
        vif_dropped_list.append(feature_to_remove)
    else:
        # Success! All features are under the threshold
        print("--- All features are now under the VIF threshold ---")
        break

# Final display
print(f"Total dropped by VIF: {vif_dropped_list}")
final_vif_report = calc_vif(X_vif_recursive)
print(final_vif_report)
# Out:
# Removing 'instant' with VIF: 2233.92
# Removing 'weekday' with VIF: 45.19
# Removing 'season' with VIF: 39.69
# Removing 'temp' with VIF: 33.39
# Removing 'hum' with VIF: 19.21
# Removing 'leaflets' with VIF: 11.60
# --- All features are now under the VIF threshold ---
# Total dropped by VIF: ['instant', 'weekday', 'season', 'temp', 'hum', 'leaflets']
#        features  VIF Factor
# 1          mnth    9.103210
# 4    weathersit    6.575710
# 5     windspeed    5.682431
# 8      mnth_sin    5.347981
# 6    season_sin    5.079491
# 7    season_cos    4.849014
# 9      mnth_cos    4.627068
# 3    workingday    4.387647
# 0            yr    1.946235
# 10  weekday_sin    1.464135
# 2       holiday    1.253670

# %%
# Sync the validation set to match the VIF-cleansed training set
X_train_reduced = X_train_reduced.drop(columns=vif_dropped_list)
X_val_reduced = X_val_reduced.drop(columns=vif_dropped_list)

print(X_train_reduced.shape)
print(X_val_reduced.shape)
# Out:
# (480, 11)
# (120, 11)

# %% [markdown]
# # Baseline after feature selection

# %% [markdown]
# ## Decision Tree

# %%
# Define max_depth and min_samples_leaf
pruned_reduced_dt = DecisionTreeRegressor(
    max_depth=10, 
    min_samples_leaf=10, 
    random_state=42
)

# Time the training
start = time.time()
pruned_dt.fit(X_train_reduced, y_train)
duration = time.time() - start

# Record the new improved result
record_performance(
    "Decision Tree", 
    pruned_dt, 
    X_train_reduced, y_train, 
    X_val_reduced, y_val, 
    train_time=duration, 
    notes="Stabilized: Pruned and reduced features",
    step="Reduced Features",
)
# Out:
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
#
#       Val R2  Train Time (s)                                    Notes
# 0   0.221641          0.0066           Default parameters, no scaling
# 1  -0.805838          0.0097           Default parameters, no scaling
# 2  -0.002225          0.0125           Default parameters, no scaling
# 3   0.091054          0.0000           Default parameters, no scaling
# 4  -0.044472          0.2943           Default parameters, no scaling
# 5  -0.573390          0.0769           Default parameters, no scaling
# 6   0.250635          0.0258           Default parameters, no scaling
# 7   0.296183          1.3035           Default parameters, no scaling
# 8   0.204066          0.0053                       Stabilized: Pruned
# 9   0.285295          0.2145                       Stabilized: Pruned
# 10  0.123445          0.2482        Stabilized: Pruned and randomized
# 11  0.174405          0.0755                    Stabilized: Throttled
# 12  0.314068          1.3817                  Stabilized: Regularized
# 13  0.221641          0.0000                       Stabilized: Scaled
# 14  0.367226          0.0015                 Stabilized: Scaled + k=7
# 15  0.264364          0.0159              Stabilized: Scaled + C=1000
# 16  0.294862          0.0056  Stabilized: Pruned and reduced features

# %% [markdown]
# ## Random Forest

# %%
# Limit depth and stablish min samples per leaf for generalization
pruned_reduced_rf = RandomForestRegressor(
    max_depth=12,          # Stop trees from getting too specific
    min_samples_leaf=5,    # Each leaf must represent at least 5 bike rentals
    random_state=42
)

start = time.time()
pruned_reduced_rf.fit(X_train_reduced, y_train)
duration = time.time() - start

record_performance("Random Forest", pruned_reduced_rf, X_train_reduced, y_train, X_val_reduced, y_val, duration, notes="Stabilized: Pruned + Reduced features", step="Reduced Features")
# Out:
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
#
#       Val R2  Train Time (s)                                    Notes
# 0   0.221641          0.0066           Default parameters, no scaling
# 1  -0.805838          0.0097           Default parameters, no scaling
# 2  -0.002225          0.0125           Default parameters, no scaling
# 3   0.091054          0.0000           Default parameters, no scaling
# 4  -0.044472          0.2943           Default parameters, no scaling
# 5  -0.573390          0.0769           Default parameters, no scaling
# 6   0.250635          0.0258           Default parameters, no scaling
# 7   0.296183          1.3035           Default parameters, no scaling
# 8   0.204066          0.0053                       Stabilized: Pruned
# 9   0.285295          0.2145                       Stabilized: Pruned
# 10  0.123445          0.2482        Stabilized: Pruned and randomized
# 11  0.174405          0.0755                    Stabilized: Throttled
# 12  0.314068          1.3817                  Stabilized: Regularized
# 13  0.221641          0.0000                       Stabilized: Scaled
# 14  0.367226          0.0015                 Stabilized: Scaled + k=7
# 15  0.264364          0.0159              Stabilized: Scaled + C=1000
# 16  0.294862          0.0056  Stabilized: Pruned and reduced features
# 17  0.323222          0.1141    Stabilized: Pruned + Reduced features

# %% [markdown]
# ## CatBoost

# %%
improved_reduced_cat = CatBoostRegressor(
    n_estimators=500,
    learning_rate=0.05,
    depth=8,
    random_state=42,
    verbose=0
)

start = time.time()
improved_reduced_cat.fit(X_train_reduced, y_train)
duration = time.time() - start

record_performance("CatBoost", improved_reduced_cat, X_train_reduced, y_train, X_val_reduced, y_val, duration, notes="Stabilized: Regularized + Reduced features", step="Reduced Features")
# Out:
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
#
#       Val R2  Train Time (s)                                       Notes
# 0   0.221641          0.0066              Default parameters, no scaling
# 1  -0.805838          0.0097              Default parameters, no scaling
# 2  -0.002225          0.0125              Default parameters, no scaling
# 3   0.091054          0.0000              Default parameters, no scaling
# 4  -0.044472          0.2943              Default parameters, no scaling
# 5  -0.573390          0.0769              Default parameters, no scaling
# 6   0.250635          0.0258              Default parameters, no scaling
# 7   0.296183          1.3035              Default parameters, no scaling
# 8   0.204066          0.0053                          Stabilized: Pruned
# 9   0.285295          0.2145                          Stabilized: Pruned
# 10  0.123445          0.2482           Stabilized: Pruned and randomized
# 11  0.174405          0.0755                       Stabilized: Throttled
# 12  0.314068          1.3817                     Stabilized: Regularized
# 13  0.221641          0.0000                          Stabilized: Scaled
# 14  0.367226          0.0015                    Stabilized: Scaled + k=7
# 15  0.264364          0.0159                 Stabilized: Scaled + C=1000
# 16  0.294862          0.0056     Stabilized: Pruned and reduced features
# 17  0.323222          0.1141       Stabilized: Pruned + Reduced features
# 18  0.260171          1.2086  Stabilized: Regularized + Reduced features

# %% [markdown]
# ## Support Vector Regression

# %%
# Initialize the Scaler
std_scaler = StandardScaler()

# Fit and Transform Training data
X_train_scaled_reduced = std_scaler.fit_transform(X_train_reduced)

# Transform Validation data
X_val_scaled_reduced = std_scaler.transform(X_val_reduced)

# %%
# SVR is extremely sensitive to scaling
improved_reduced_svr = SVR(C=1000, epsilon=10)

start = time.time()
improved_reduced_svr.fit(X_train_scaled_reduced, y_train) # Use SCALED data
duration = time.time() - start

record_performance("SVR", improved_reduced_svr, X_train_scaled_reduced, y_train, X_val_scaled_reduced, y_val, duration, notes="Stabilized: Scaled + C=1000 + Reduced features", step="Reduced Features")
# Out:
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
#
#       Val R2  Train Time (s)                                           Notes
# 0   0.221641          0.0066                  Default parameters, no scaling
# 1  -0.805838          0.0097                  Default parameters, no scaling
# 2  -0.002225          0.0125                  Default parameters, no scaling
# 3   0.091054          0.0000                  Default parameters, no scaling
# 4  -0.044472          0.2943                  Default parameters, no scaling
# 5  -0.573390          0.0769                  Default parameters, no scaling
# 6   0.250635          0.0258                  Default parameters, no scaling
# 7   0.296183          1.3035                  Default parameters, no scaling
# 8   0.204066          0.0053                              Stabilized: Pruned
# 9   0.285295          0.2145                              Stabilized: Pruned
# 10  0.123445          0.2482               Stabilized: Pruned and randomized
# 11  0.174405          0.0755                           Stabilized: Throttled
# 12  0.314068          1.3817                         Stabilized: Regularized
# 13  0.221641          0.0000                              Stabilized: Scaled
# 14  0.367226          0.0015                        Stabilized: Scaled + k=7
# 15  0.264364          0.0159                     Stabilized: Scaled + C=1000
# 16  0.294862          0.0056         Stabilized: Pruned and reduced features
# 17  0.323222          0.1141           Stabilized: Pruned + Reduced features
# 18  0.260171          1.2086      Stabilized: Regularized + Reduced features
# 19  0.205541          0.0082  Stabilized: Scaled + C=1000 + Reduced features

# %% [markdown]
# ## Linear Regression

# %%
# We use the SCALED data here so we can compare feature importance later
improved_reduced_lr = LinearRegression()

start = time.time()
improved_reduced_lr.fit(X_train_scaled_reduced, y_train)
duration = time.time() - start

record_performance("Linear Regression", improved_reduced_lr, X_train_scaled_reduced, y_train, X_val_scaled_reduced, y_val, duration, notes="Stabilized: Scaled + Reduced features", step="Reduced Features")
# Out:
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
#
#       Val R2  Train Time (s)                                           Notes
# 0   0.221641          0.0066                  Default parameters, no scaling
# 1  -0.805838          0.0097                  Default parameters, no scaling
# 2  -0.002225          0.0125                  Default parameters, no scaling
# 3   0.091054          0.0000                  Default parameters, no scaling
# 4  -0.044472          0.2943                  Default parameters, no scaling
# 5  -0.573390          0.0769                  Default parameters, no scaling
# 6   0.250635          0.0258                  Default parameters, no scaling
# 7   0.296183          1.3035                  Default parameters, no scaling
# 8   0.204066          0.0053                              Stabilized: Pruned
# 9   0.285295          0.2145                              Stabilized: Pruned
# 10  0.123445          0.2482               Stabilized: Pruned and randomized
# 11  0.174405          0.0755                           Stabilized: Throttled
# 12  0.314068          1.3817                         Stabilized: Regularized
# 13  0.221641          0.0000                              Stabilized: Scaled
# 14  0.367226          0.0015                        Stabilized: Scaled + k=7
# 15  0.264364          0.0159                     Stabilized: Scaled + C=1000
# 16  0.294862          0.0056         Stabilized: Pruned and reduced features
# 17  0.323222          0.1141           Stabilized: Pruned + Reduced features
# 18  0.260171          1.2086      Stabilized: Regularized + Reduced features
# 19  0.205541          0.0082  Stabilized: Scaled + C=1000 + Reduced features
# 20  0.183316          0.0011           Stabilized: Scaled + Reduced features

# %% [markdown]
# ## K-NN

# %%
# Increasing neighbors usually helps smooth out predictions
improved_reduced_knn = KNeighborsRegressor(n_neighbors=7, weights='uniform')

start = time.time()
improved_reduced_knn.fit(X_train_scaled_reduced, y_train) # Use SCALED data
duration = time.time() - start

record_performance("k-NN", improved_reduced_knn, X_train_scaled_reduced, y_train, X_val_scaled_reduced, y_val, duration, notes="Stabilized: Scaled + k=7 + reduced features", step="Reduced Features",)
# Out:
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
#
#       Val R2  Train Time (s)                                           Notes
# 0   0.221641          0.0066                  Default parameters, no scaling
# 1  -0.805838          0.0097                  Default parameters, no scaling
# 2  -0.002225          0.0125                  Default parameters, no scaling
# 3   0.091054          0.0000                  Default parameters, no scaling
# 4  -0.044472          0.2943                  Default parameters, no scaling
# 5  -0.573390          0.0769                  Default parameters, no scaling
# 6   0.250635          0.0258                  Default parameters, no scaling
# 7   0.296183          1.3035                  Default parameters, no scaling
# 8   0.204066          0.0053                              Stabilized: Pruned
# 9   0.285295          0.2145                              Stabilized: Pruned
# 10  0.123445          0.2482               Stabilized: Pruned and randomized
# 11  0.174405          0.0755                           Stabilized: Throttled
# 12  0.314068          1.3817                         Stabilized: Regularized
# 13  0.221641          0.0000                              Stabilized: Scaled
# 14  0.367226          0.0015                        Stabilized: Scaled + k=7
# 15  0.264364          0.0159                     Stabilized: Scaled + C=1000
# 16  0.294862          0.0056         Stabilized: Pruned and reduced features
# 17  0.323222          0.1141           Stabilized: Pruned + Reduced features
# 18  0.260171          1.2086      Stabilized: Regularized + Reduced features
# 19  0.205541          0.0082  Stabilized: Scaled + C=1000 + Reduced features
# 20  0.183316          0.0011           Stabilized: Scaled + Reduced features
# 21  0.348615          0.0016     Stabilized: Scaled + k=7 + reduced features

# %% [markdown]
# ## Show results

# %%
# View results
results = get_performance_summary(sort_by="Model")
display(results)
# Out:
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
#
#       Val R2  Train Time (s)                                           Notes
# 12  0.314068          1.3817                         Stabilized: Regularized
# 7   0.296183          1.3035                  Default parameters, no scaling
# 18  0.260171          1.2086      Stabilized: Regularized + Reduced features
# 8   0.204066          0.0053                              Stabilized: Pruned
# 16  0.294862          0.0056         Stabilized: Pruned and reduced features
# 1  -0.805838          0.0097                  Default parameters, no scaling
# 6   0.250635          0.0258                  Default parameters, no scaling
# 11  0.174405          0.0755                           Stabilized: Throttled
# 20  0.183316          0.0011           Stabilized: Scaled + Reduced features
# 13  0.221641          0.0000                              Stabilized: Scaled
# 0   0.221641          0.0066                  Default parameters, no scaling
# 9   0.285295          0.2145                              Stabilized: Pruned
# 17  0.323222          0.1141           Stabilized: Pruned + Reduced features
# 4  -0.044472          0.2943                  Default parameters, no scaling
# 19  0.205541          0.0082  Stabilized: Scaled + C=1000 + Reduced features
# 2  -0.002225          0.0125                  Default parameters, no scaling
# 15  0.264364          0.0159                     Stabilized: Scaled + C=1000
# 10  0.123445          0.2482               Stabilized: Pruned and randomized
# 5  -0.573390          0.0769                  Default parameters, no scaling
# 3   0.091054          0.0000                  Default parameters, no scaling
# 14  0.367226          0.0015                        Stabilized: Scaled + k=7
# 21  0.348615          0.0016     Stabilized: Scaled + k=7 + reduced features

# %%
# Show results in graph
show_summary_graph(results, steps_to_show=["Stabilized", "Reduced Features"])

# %% [markdown]
# ### Partial conclusions after feature selection

# %% [markdown]
# - After feature selection most all the models performance dropped compared to the models before feature selection.
# - Even when the methods of feature selection detect attributes with no so hight relevance indepentdently. Together they may iclude some information that is usefull for the models.

# %% [markdown]
# # Model Hyperparameter Optimization

# %% [markdown]
# ## Linear Regression

# %%
# Define the parameter grid for Linear Regression
param_grid_lr = {
    'fit_intercept': [True, False],
    'positive': [True, False]
}

# Initialize GridSearchCV
# Using 5-fold cross-validation and R-squared as the scoring metric
grid_lr = GridSearchCV(LinearRegression(), param_grid_lr, cv=5, scoring='neg_mean_absolute_error')

# Training
start = time.time()
# Train on the TRAINING set
grid_lr.fit(X_train_scaled, y_train)
end = time.time()
duration = end - start

# Get the best estimator
best_lr_model = grid_lr.best_estimator_
print("Best Parameters:", grid_lr.best_params_)

# Record and display results
record_performance("Linear Regression", best_lr_model, X_train_scaled, y_train, X_val_scaled, y_val, duration, notes=f"GridSearch: {grid_lr.best_params_}", step="Optimized")
# Out:
# Best Parameters: {'fit_intercept': True, 'positive': False}
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
# 22  Linear Regression         Optimized   859.281939  1341.873287  0.353380
#
#       Val R2  Train Time (s)  \
# 0   0.221641          0.0110
# 1  -0.805838          0.0090
# 2  -0.002225          0.0100
# 3   0.091054          0.0010
# 4  -0.044472          0.2779
# 5  -0.573390          0.0780
# 6   0.250635          0.0300
# 7   0.296183          1.3378
# 8   0.204066          0.0040
# 9   0.285295          0.1920
# 10  0.123445          0.3043
# 11  0.174405          0.0886
# 12  0.314068          1.3392
# 13  0.221641          0.0020
# 14  0.367226          0.0010
# 15  0.264364          0.0141
# 16  0.294862          0.0020
# 17  0.323222          0.1178
# 18  0.260171          1.1844
# 19  0.205541          0.0140
# 20  0.183316          0.0020
# 21  0.348615          0.0020
# 22  0.221641          0.0344
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'fit_intercept': True, 'positive'...

# %% [markdown]
# ## Regression Tree

# %%
# Define the parameter grid for the Decision Tree
param_grid_dt = {
    'max_depth': [5, 10, 15, 20],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}

# Initialize GridSearchCV
# Scoring by R-squared is common for regression
grid_dt = GridSearchCV(DecisionTreeRegressor(random_state=42), param_grid_dt, cv=5, scoring='neg_mean_absolute_error')

# Training
start = time.time()
# Train on the TRAINING set
grid_dt.fit(X_train, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_dt.best_params_)
best_dt_model = grid_dt.best_estimator_

# Record and display the results
record_performance("Decision Tree", best_dt_model, X_train, y_train, X_val, y_val, duration, notes=f"GridSearch: {grid_dt.best_params_}", step="Optimized")
# Out:
# Best Parameters: {'max_depth': 5, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
# 22  Linear Regression         Optimized   859.281939  1341.873287  0.353380
# 23      Decision Tree         Optimized   716.713436  1152.685411  0.521473
#
#       Val R2  Train Time (s)  \
# 0   0.221641          0.0110
# 1  -0.805838          0.0090
# 2  -0.002225          0.0100
# 3   0.091054          0.0010
# 4  -0.044472          0.2779
# 5  -0.573390          0.0780
# 6   0.250635          0.0300
# 7   0.296183          1.3378
# 8   0.204066          0.0040
# 9   0.285295          0.1920
# 10  0.123445          0.3043
# 11  0.174405          0.0886
# 12  0.314068          1.3392
# 13  0.221641          0.0020
# 14  0.367226          0.0010
# 15  0.264364          0.0141
# 16  0.294862          0.0020
# 17  0.323222          0.1178
# 18  0.260171          1.1844
# 19  0.205541          0.0140
# 20  0.183316          0.0020
# 21  0.348615          0.0020
# 22  0.221641          0.0344
# 23  0.250802          2.4963
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'fit_intercept': True, 'positive'...
# 23  GridSearch: {'max_depth': 5, 'max_features': N...

# %% [markdown]
# ## Support Vector Regressor

# %%
# Define the parameter grid for SVR
# SVR is sensitive to the scale of data and its hyperparameters.
param_grid_svr = {
    'C': [0.1, 1, 10, 100, 1000, 4000, 6000, 8000],     # Regularization parameter
    'epsilon': [0.1, 1, 10, 40, 80, 100, 150],          # Specifies the epsilon-tube within which no penalty is associated
    'kernel': ['linear', 'rbf'],                        # Trying both linear and non-linear patterns
    'gamma': ['scale', 'auto']                          # Kernel coefficient for 'rbf' ['scale', 'auto', 0.01, 0.1, 1]   
}

# Initialize GridSearchCV
# Using n_jobs=-1 will use all your CPU cores to speed up the search
grid_svr = GridSearchCV(SVR(), param_grid_svr, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1)

# Training
start = time.time()
# Train on the TRAINING set
grid_svr.fit(X_train_scaled, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_svr.best_params_)
best_svr_model = grid_svr.best_estimator_

# Record and display the results
record_performance("SVR", best_svr_model, X_train_scaled, y_train, X_val_scaled, y_val, duration, notes=f"GridSearch: {grid_svr.best_params_}", step="Optimized")
# Out:
# Best Parameters: {'C': 4000, 'epsilon': 80, 'gamma': 'scale', 'kernel': 'rbf'}
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
# 22                SVR         Optimized   334.707420   928.135348  0.389417
#
#       Val R2  Train Time (s)  \
# 0   0.221641          0.0066
# 1  -0.805838          0.0097
# 2  -0.002225          0.0125
# 3   0.091054          0.0000
# 4  -0.044472          0.2943
# 5  -0.573390          0.0769
# 6   0.250635          0.0258
# 7   0.296183          1.3035
# 8   0.204066          0.0053
# 9   0.285295          0.2145
# 10  0.123445          0.2482
# 11  0.174405          0.0755
# 12  0.314068          1.3817
# 13  0.221641          0.0000
# 14  0.367226          0.0015
# 15  0.264364          0.0159
# 16  0.294862          0.0056
# 17  0.323222          0.1141
# 18  0.260171          1.2086
# 19  0.205541          0.0082
# 20  0.183316          0.0011
# 21  0.348615          0.0016
# 22  0.296177         20.7500
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'C': 4000, 'epsilon': 80, 'gamma'...

# %% [markdown]
# ## KNN

# %%
# Define the parameter grid for k-NN
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],  # 'distance' weight points by the inverse of their distance
    'p': [1, 2]                          # 1 = Manhattan distance, 2 = Euclidean distance
}

# Initialize GridSearchCV
grid_knn = GridSearchCV(KNeighborsRegressor(), param_grid_knn, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1)

# Training
start = time.time()
# Train on the TRAINING set
grid_knn.fit(X_train_scaled, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_knn.best_params_)
best_knn_model = grid_knn.best_estimator_

# Record and display the results
record_performance("K-NN", best_knn_model, X_train_scaled, y_train, X_val_scaled, y_val, duration, notes=f"GridSearch: {grid_knn.best_params_}", step="Optimized")
# Out:
# Best Parameters: {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
# 22                SVR         Optimized   334.707420   928.135348  0.389417
# 23                KNN         Optimized     0.000000  1008.578950  1.000000
#
#       Val R2  Train Time (s)  \
# 0   0.221641          0.0066
# 1  -0.805838          0.0097
# 2  -0.002225          0.0125
# 3   0.091054          0.0000
# 4  -0.044472          0.2943
# 5  -0.573390          0.0769
# 6   0.250635          0.0258
# 7   0.296183          1.3035
# 8   0.204066          0.0053
# 9   0.285295          0.2145
# 10  0.123445          0.2482
# 11  0.174405          0.0755
# 12  0.314068          1.3817
# 13  0.221641          0.0000
# 14  0.367226          0.0015
# 15  0.264364          0.0159
# 16  0.294862          0.0056
# 17  0.323222          0.1141
# 18  0.260171          1.2086
# 19  0.205541          0.0082
# 20  0.183316          0.0011
# 21  0.348615          0.0016
# 22  0.296177         20.7500
# 23  0.537839          0.3016
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'C': 4000, 'epsilon': 80, 'gamma'...
# 23  GridSearch: {'n_neighbors': 3, 'p': 1, 'weight...

# %% [markdown]
# ## Random Forest

# %%
# Define the parameter grid for Random Forest
param_grid_rf = {
    'n_estimators': [100, 300, 400, 500],        # Number of trees in the forest
    'max_depth': [None, 10, 12, 20],        # Depth of each tree
    'min_samples_split': [2, 5, 10],        # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4, 5],       # Minimum samples required at each leaf node
    'max_features': ['sqrt', 'log2', None]  # Number of features to consider at each split
}

# Initialize GridSearchCV
# Using n_jobs=-1 is highly recommended as Random Forest is computationally expensive
grid_rf = GridSearchCV(RandomForestRegressor(random_state=42), param_grid_rf, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1)

# Training
start = time.time()
# Train on the TRAINING set
grid_rf.fit(X_train, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_rf.best_params_)
best_rf_model = grid_rf.best_estimator_

# Record and display the results
record_performance("Random Forest", best_rf_model, X_train, y_train, X_val, y_val, duration, notes=f"GridSearch: {grid_rf.best_params_}", step="Optimized")
# Out:
# Best Parameters: {'max_depth': 12, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 400}
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
# 22                SVR         Optimized   334.707420   928.135348  0.389417
# 23                KNN         Optimized     0.000000  1008.578950  1.000000
# 24      Random Forest         Optimized   447.810895   984.800711  0.685664
#
#       Val R2  Train Time (s)  \
# 0   0.221641          0.0066
# 1  -0.805838          0.0097
# 2  -0.002225          0.0125
# 3   0.091054          0.0000
# 4  -0.044472          0.2943
# 5  -0.573390          0.0769
# 6   0.250635          0.0258
# 7   0.296183          1.3035
# 8   0.204066          0.0053
# 9   0.285295          0.2145
# 10  0.123445          0.2482
# 11  0.174405          0.0755
# 12  0.314068          1.3817
# 13  0.221641          0.0000
# 14  0.367226          0.0015
# 15  0.264364          0.0159
# 16  0.294862          0.0056
# 17  0.323222          0.1141
# 18  0.260171          1.2086
# 19  0.205541          0.0082
# 20  0.183316          0.0011
# 21  0.348615          0.0016
# 22  0.296177         20.7500
# 23  0.537839          0.3016
# 24  0.287620        178.5577
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'C': 4000, 'epsilon': 80, 'gamma'...
# 23  GridSearch: {'n_neighbors': 3, 'p': 1, 'weight...
# 24  GridSearch: {'max_depth': 12, 'max_features': ...

# %% [markdown]
# ## XGBoost

# %%
# Define the parameter grid for XGBoost
param_grid_xgb = {
    'n_estimators': [500, 1000, 2000],           # Number of boosting rounds
    'learning_rate': [0.05, 0.1],   # Step size shrinkage
    'max_depth': [5, 7],               # Maximum depth of a tree
    'subsample': [0.7, 0.8, 1.0],         # Fraction of samples used per tree
    'colsample_bytree': [0.7, 0.8, 1.0]   # Fraction of features used per tree
}

# Initialize GridSearchCV
# n_jobs=-1 helps speed up the process
grid_xgb = GridSearchCV(XGBRegressor(random_state=42), param_grid_xgb, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1)

# Training
start = time.time()
# Train on the TRAINING set
grid_xgb.fit(X_train, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_xgb.best_params_)
best_xgb_model = grid_xgb.best_estimator_

# Record and display the results
record_performance("XGBoost", best_xgb_model, X_train, y_train, X_val, y_val, duration, notes=f"GridSearch: {grid_xgb.best_params_}", step="Optimized")
# Out:
# Best Parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'subsample': 0.7}
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
# 22                SVR         Optimized   334.707420   928.135348  0.389417
# 23                KNN         Optimized     0.000000  1008.578950  1.000000
# 24      Random Forest         Optimized   447.810895   984.800711  0.685664
# 25            XGBoost         Optimized    41.436245  1286.688721  0.999753
#
#       Val R2  Train Time (s)  \
# 0   0.221641          0.0066
# 1  -0.805838          0.0097
# 2  -0.002225          0.0125
# 3   0.091054          0.0000
# 4  -0.044472          0.2943
# 5  -0.573390          0.0769
# 6   0.250635          0.0258
# 7   0.296183          1.3035
# 8   0.204066          0.0053
# 9   0.285295          0.2145
# 10  0.123445          0.2482
# 11  0.174405          0.0755
# 12  0.314068          1.3817
# 13  0.221641          0.0000
# 14  0.367226          0.0015
# 15  0.264364          0.0159
# 16  0.294862          0.0056
# 17  0.323222          0.1141
# 18  0.260171          1.2086
# 19  0.205541          0.0082
# 20  0.183316          0.0011
# 21  0.348615          0.0016
# 22  0.296177         20.7500
# 23  0.537839          0.3016
# 24  0.287620        178.5577
# 25  0.121528         70.3684
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'C': 4000, 'epsilon': 80, 'gamma'...
# 23  GridSearch: {'n_neighbors': 3, 'p': 1, 'weight...
# 24  GridSearch: {'max_depth': 12, 'max_features': ...
# 25  GridSearch: {'colsample_bytree': 0.7, 'learnin...

# %% [markdown]
# ## LightGBM

# %%
# Define the parameter grid for LightGBM
param_grid_lgbm = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.05, 0.1],
    'num_leaves': [20, 31, 40],           # Main parameter to control complexity
    'max_depth': [-1, 5, 7, 10],            # -1 means no limit
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0]
}

# Initialize GridSearchCV
# Using verbosity=-1 in the model helps keep the logs clean during the search
grid_lgbm = GridSearchCV(
    LGBMRegressor(random_state=42, verbosity=-1), 
    param_grid_lgbm, 
    cv=5, 
    scoring='neg_mean_absolute_error', 
    n_jobs=-1
)

# Training
start = time.time()
# Train on the TRAINING set
grid_lgbm.fit(X_train, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_lgbm.best_params_)
best_lgbm_model = grid_lgbm.best_estimator_

# Record and display the results
record_performance("LightGBM", best_lgbm_model, X_train, y_train, X_val, y_val, duration, notes=f"GridSearch: {grid_lgbm.best_params_}", step="Optimized")
# Out:
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 20, 'subsample': 0.7}
#                    Model              Step    Train MAE      Val MAE  \
# 0      Linear Regression          Baseline   859.281939  1341.873287
# 1          Decision Tree          Baseline     0.000000  1454.975000
# 2                    SVR          Baseline  1716.059980  1976.854782
# 3                   k-NN          Baseline   773.838333  1461.456667
# 4          Random Forest          Baseline   307.633542  1304.098167
# 5                XGBoost          Baseline     5.945889  1459.346924
# 6               LightGBM          Baseline   437.941413  1200.831472
# 7               CatBoost          Baseline   123.638364  1016.564289
# 8          Decision Tree        Stabilized   707.592570  1270.124265
# 9          Random Forest        Stabilized   608.068712  1100.454092
# 10               XGBoost        Stabilized    37.347328  1203.684814
# 11              LightGBM        Stabilized   368.857442  1357.610999
# 12              CatBoost        Stabilized   109.159958  1000.621020
# 13     Linear Regression        Stabilized   859.281939  1341.873287
# 14                  k-NN        Stabilized   795.725893  1237.861905
# 15                   SVR        Stabilized   464.347225   984.390504
# 16         Decision Tree  Reduced Features   853.659379  1295.660322
# 17         Random Forest  Reduced Features   746.465408  1295.291365
# 18              CatBoost  Reduced Features   274.623357  1266.219826
# 19                   SVR  Reduced Features   636.608415  1175.492624
# 20     Linear Regression  Reduced Features   902.768848  1416.311151
# 21                  k-NN  Reduced Features   798.713393  1246.660714
# 22  LightGBM (Optimized)         Optimized   520.251346  1123.581035
#
#     Train R2    Val R2  Train Time (s)  \
# 0   0.353380  0.221641          0.0030
# 1   1.000000 -0.805838          0.0086
# 2   0.004826 -0.002225          0.0119
# 3   0.487123  0.091054          0.0000
# 4   0.883017 -0.044472          0.2851
# 5   0.999993 -0.573390          0.0701
# 6   0.718793  0.250635          0.0310
# 7   0.997751  0.296183          1.3366
# 8   0.470122  0.204066          0.0043
# 9   0.547521  0.285295          0.1833
# 10  0.999793  0.123445          0.2382
# 11  0.883220  0.174405          0.0751
# 12  0.998198  0.314068          1.3406
# 13  0.353380  0.221641          0.0010
# 14  0.461550  0.367226          0.0010
# 15  0.363713  0.264364          0.0150
# 16  0.379912  0.294862          0.0030
# 17  0.458854  0.323222          0.1155
# 18  0.988730  0.260171          1.2043
# 19  0.342374  0.205541          0.0140
# 20  0.330132  0.183316          0.0016
# 21  0.457854  0.348615          0.0010
# 22  0.596108  0.288561         88.7670
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'colsample_bytree': 1.0, 'learnin...

# %% [markdown]
# ## CatBoost

# %%
# Define the parameter grid for LightGBM
param_grid_cat = {
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'l2_leaf_reg': [1, 5, 10],
    'iterations': [1000, 1500]
}

# Initialize GridSearchCV
# Using verbosity=-1 in the model helps keep the logs clean during the search
grid_cat = GridSearchCV(
    CatBoostRegressor(random_state=42), 
    param_grid_cat, 
    cv=5, 
    scoring='neg_mean_absolute_error', 
    n_jobs=-1
)

# Training
start = time.time()
# Train on the TRAINING set
grid_cat.fit(X_train, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_cat.best_params_)
best_cat_model = grid_cat.best_estimator_

# Record and display the results
record_performance("CatBoost", best_cat_model, X_train, y_train, X_val, y_val, duration, notes=f"GridSearch: {grid_cat.best_params_}", step="Optimized")
# Out:
# 0:	learn: 3390.7172729	total: 4.2ms	remaining: 6.3s
# 1:	learn: 3372.2776723	total: 7.3ms	remaining: 5.47s
# 2:	learn: 3358.5288787	total: 9.25ms	remaining: 4.61s
# 3:	learn: 3339.4819674	total: 12.5ms	remaining: 4.67s
# 4:	learn: 3320.7272692	total: 15.6ms	remaining: 4.66s
# 5:	learn: 3307.7893466	total: 17.4ms	remaining: 4.34s
# 6:	learn: 3290.3196725	total: 20.6ms	remaining: 4.4s
# 7:	learn: 3276.9051306	total: 23.6ms	remaining: 4.4s
# 8:	learn: 3259.3852327	total: 26.9ms	remaining: 4.46s
# 9:	learn: 3246.5232331	total: 29.9ms	remaining: 4.45s
# 10:	learn: 3229.1153777	total: 33.1ms	remaining: 4.47s
# 11:	learn: 3213.7882997	total: 36ms	remaining: 4.47s
# 12:	learn: 3195.7615503	total: 39.2ms	remaining: 4.48s
# 13:	learn: 3178.6821197	total: 42.5ms	remaining: 4.51s
# 14:	learn: 3161.2157852	total: 45.7ms	remaining: 4.52s
# 15:	learn: 3144.6092868	total: 48.9ms	remaining: 4.54s
# 16:	learn: 3127.1172732	total: 51.9ms	remaining: 4.52s
# 17:	learn: 3115.7677975	total: 53.1ms	remaining: 4.37s
# 18:	learn: 3101.0092693	total: 56.4ms	remaining: 4.4s
# 19:	learn: 3083.9642045	total: 59.5ms	remaining: 4.41s
# 20:	learn: 3067.2341546	total: 62.7ms	remaining: 4.42s
# 21:	learn: 3052.9947710	total: 65.9ms	remaining: 4.43s
# 22:	learn: 3041.1660215	total: 69ms	remaining: 4.43s
# 23:	learn: 3025.2823063	total: 72.2ms	remaining: 4.44s
# 24:	learn: 3009.4143945	total: 75.5ms	remaining: 4.46s
# 1489:	learn: 147.6213252	total: 4.15s	remaining: 27.9ms
# 1490:	learn: 147.4286532	total: 4.16s	remaining: 25.1ms
# 1491:	learn: 147.3556031	total: 4.16s	remaining: 22.3ms
# 1492:	learn: 147.2916749	total: 4.16s	remaining: 19.5ms
# 1493:	learn: 147.1043976	total: 4.17s	remaining: 16.7ms
# 1494:	learn: 146.8487565	total: 4.17s	remaining: 13.9ms
# 1495:	learn: 146.7743076	total: 4.17s	remaining: 11.2ms
# 1496:	learn: 146.6669593	total: 4.17s	remaining: 8.36ms
# 1497:	learn: 146.5245175	total: 4.18s	remaining: 5.58ms
# 1498:	learn: 146.3385730	total: 4.18s	remaining: 2.79ms
# 1499:	learn: 146.1599632	total: 4.18s	remaining: 0us
# Best Parameters: {'depth': 8, 'iterations': 1500, 'l2_leaf_reg': 1, 'learning_rate': 0.01}
#                    Model              Step    Train MAE      Val MAE  \
# 0      Linear Regression          Baseline   859.281939  1341.873287
# 1          Decision Tree          Baseline     0.000000  1454.975000
# 2                    SVR          Baseline  1716.059980  1976.854782
# 3                   k-NN          Baseline   773.838333  1461.456667
# 4          Random Forest          Baseline   307.633542  1304.098167
# 5                XGBoost          Baseline     5.945889  1459.346924
# 6               LightGBM          Baseline   437.941413  1200.831472
# 7               CatBoost          Baseline   123.638364  1016.564289
# 8          Decision Tree        Stabilized   707.592570  1270.124265
# 9          Random Forest        Stabilized   608.068712  1100.454092
# 10               XGBoost        Stabilized    37.347328  1203.684814
# 11              LightGBM        Stabilized   368.857442  1357.610999
# 12              CatBoost        Stabilized   109.159958  1000.621020
# 13     Linear Regression        Stabilized   859.281939  1341.873287
# 14                  k-NN        Stabilized   795.725893  1237.861905
# 15                   SVR        Stabilized   464.347225   984.390504
# 16         Decision Tree  Reduced Features   853.659379  1295.660322
# 17         Random Forest  Reduced Features   746.465408  1295.291365
# 18              CatBoost  Reduced Features   274.623357  1266.219826
# 19                   SVR  Reduced Features   636.608415  1175.492624
# 20     Linear Regression  Reduced Features   902.768848  1416.311151
# 21                  k-NN  Reduced Features   798.713393  1246.660714
# 22  LightGBM (Optimized)         Optimized   520.251346  1123.581035
# 23  CatBoost (Optimized)         Optimized   112.458292   966.053678
#
#     Train R2    Val R2  Train Time (s)  \
# 0   0.353380  0.221641          0.0030
# 1   1.000000 -0.805838          0.0086
# 2   0.004826 -0.002225          0.0119
# 3   0.487123  0.091054          0.0000
# 4   0.883017 -0.044472          0.2851
# 5   0.999993 -0.573390          0.0701
# 6   0.718793  0.250635          0.0310
# 7   0.997751  0.296183          1.3366
# 8   0.470122  0.204066          0.0043
# 9   0.547521  0.285295          0.1833
# 10  0.999793  0.123445          0.2382
# 11  0.883220  0.174405          0.0751
# 12  0.998198  0.314068          1.3406
# 13  0.353380  0.221641          0.0010
# 14  0.461550  0.367226          0.0010
# 15  0.363713  0.264364          0.0150
# 16  0.379912  0.294862          0.0030
# 17  0.458854  0.323222          0.1155
# 18  0.988730  0.260171          1.2043
# 19  0.342374  0.205541          0.0140
# 20  0.330132  0.183316          0.0016
# 21  0.457854  0.348615          0.0010
# 22  0.596108  0.288561         88.7670
# 23  0.998157  0.323849        292.6386
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'colsample_bytree': 1.0, 'learnin...
# 23  GridSearch: {'depth': 8, 'iterations': 1500, '...

# %% [markdown]
# # Show Optimized Results

# %%
# View results
results = get_performance_summary(sort_by="Model")
display(results)
# Out:
#                 Model              Step    Train MAE      Val MAE  Train R2  \
# 12           CatBoost        Stabilized   109.159958  1000.621020  0.998198
# 18           CatBoost  Reduced Features   274.623357  1266.219826  0.988730
# 7            CatBoost          Baseline   123.638364  1016.564289  0.997751
# 1       Decision Tree          Baseline     0.000000  1454.975000  1.000000
# 16      Decision Tree  Reduced Features   853.659379  1295.660322  0.379912
# 8       Decision Tree        Stabilized   707.592570  1270.124265  0.470122
# 23                KNN         Optimized     0.000000  1008.578950  1.000000
# 6            LightGBM          Baseline   437.941413  1200.831472  0.718793
# 11           LightGBM        Stabilized   368.857442  1357.610999  0.883220
# 20  Linear Regression  Reduced Features   902.768848  1416.311151  0.330132
# 13  Linear Regression        Stabilized   859.281939  1341.873287  0.353380
# 0   Linear Regression          Baseline   859.281939  1341.873287  0.353380
# 24      Random Forest         Optimized   447.810895   984.800711  0.685664
# 9       Random Forest        Stabilized   608.068712  1100.454092  0.547521
# 17      Random Forest  Reduced Features   746.465408  1295.291365  0.458854
# 4       Random Forest          Baseline   307.633542  1304.098167  0.883017
# 15                SVR        Stabilized   464.347225   984.390504  0.363713
# 19                SVR  Reduced Features   636.608415  1175.492624  0.342374
# 22                SVR         Optimized   334.707420   928.135348  0.389417
# 2                 SVR          Baseline  1716.059980  1976.854782  0.004826
# 5             XGBoost          Baseline     5.945889  1459.346924  0.999993
# 10            XGBoost        Stabilized    37.347328  1203.684814  0.999793
# 25            XGBoost         Optimized    41.436245  1286.688721  0.999753
# 14               k-NN        Stabilized   795.725893  1237.861905  0.461550
# 3                k-NN          Baseline   773.838333  1461.456667  0.487123
# 21               k-NN  Reduced Features   798.713393  1246.660714  0.457854
#
#       Val R2  Train Time (s)  \
# 12  0.314068          1.3817
# 18  0.260171          1.2086
# 7   0.296183          1.3035
# 1  -0.805838          0.0097
# 16  0.294862          0.0056
# 8   0.204066          0.0053
# 23  0.537839          0.3016
# 6   0.250635          0.0258
# 11  0.174405          0.0755
# 20  0.183316          0.0011
# 13  0.221641          0.0000
# 0   0.221641          0.0066
# 24  0.287620        178.5577
# 9   0.285295          0.2145
# 17  0.323222          0.1141
# 4  -0.044472          0.2943
# 15  0.264364          0.0159
# 19  0.205541          0.0082
# 22  0.296177         20.7500
# 2  -0.002225          0.0125
# 5  -0.573390          0.0769
# 10  0.123445          0.2482
# 25  0.121528         70.3684
# 14  0.367226          0.0015
# 3   0.091054          0.0000
# 21  0.348615          0.0016
#
#                                                 Notes
# 12                            Stabilized: Regularized
# 18         Stabilized: Regularized + Reduced features
# 7                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 16            Stabilized: Pruned and reduced features
# 8                                  Stabilized: Pruned
# 23  GridSearch: {'n_neighbors': 3, 'p': 1, 'weight...
# 6                      Default parameters, no scaling
# 11                              Stabilized: Throttled
# 20              Stabilized: Scaled + Reduced features
# 13                                 Stabilized: Scaled
# 0                      Default parameters, no scaling
# 24  GridSearch: {'max_depth': 12, 'max_features': ...
# 9                                  Stabilized: Pruned
# 17              Stabilized: Pruned + Reduced features
# 4                      Default parameters, no scaling
# 15                        Stabilized: Scaled + C=1000
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 22  GridSearch: {'C': 4000, 'epsilon': 80, 'gamma'...
# 2                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 10                  Stabilized: Pruned and randomized
# 25  GridSearch: {'colsample_bytree': 0.7, 'learnin...
# 14                           Stabilized: Scaled + k=7
# 3                      Default parameters, no scaling
# 21        Stabilized: Scaled + k=7 + reduced features

# %% [markdown]
# ## Save results to csv

# %%
results.to_csv('BikeRentalDaily_val_results-OK-2.csv', index=False)

# %%
df_viz = results.copy()
# Set up the plotting area (2 subplots: R-squared and MAE)
fig, axes = plt.subplots(1, 2, figsize=(16, 8))
# --- Plot 1: R-squared (Higher is Better) ---
sns.barplot(data=df_viz, x="Val R2", y="Model", ax=axes[0], hue="Model", palette="viridis", legend=False)
axes[0].set_title("Model Comparison: R-squared (Higher is Better)", fontsize=14)
axes[0].set_xlim(0, 1.0) 
axes[0].grid(axis='x', linestyle='--', alpha=0.7)
# --- Plot 2: MAE (Lower is Better) ---
sns.barplot(data=df_viz, x="Val MAE", y="Model", ax=axes[1], hue="Model", palette="magma", legend=False)
axes[1].set_title("Model Comparison: MAE (Lower is Better)", fontsize=14)
axes[1].set_ylabel("") 
axes[1].grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Hyperparameter optimizattion after feature selection

# %% [markdown]
# ## Support Vector Regression

# %%
# Define the parameter grid for SVR
# SVR is sensitive to the scale of data and its hyperparameters.
param_grid_svr = {
    'C': [0.1, 1, 10, 100, 1000, 4000, 6000, 8000],     # Regularization parameter
    'epsilon': [0.1, 1, 10, 40, 80, 100, 150],          # Specifies the epsilon-tube within which no penalty is associated
    'kernel': ['linear', 'rbf'],                        # Trying both linear and non-linear patterns
    'gamma': ['scale', 'auto']                          # Kernel coefficient for 'rbf' ['scale', 'auto', 0.01, 0.1, 1]   
}

# Initialize GridSearchCV
# Using n_jobs=-1 will use all your CPU cores to speed up the search
grid_svr = GridSearchCV(SVR(), param_grid_svr, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1)

# Training
start = time.time()
# Train on the TRAINING set
grid_svr.fit(X_train_scaled_reduced, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_svr.best_params_)
best_svr_model2 = grid_svr.best_estimator_

# Record and display the results
record_performance("SVR", best_svr_model2, X_train_scaled_reduced, y_train, X_val_scaled_reduced, y_val, duration, notes=f"Feature selection + GridSearch: {grid_svr.best_params_}", step="Reduced Features+Optimization")
# Out:
# Best Parameters: {'C': 1000, 'epsilon': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#                    Model                           Step    Train MAE  \
# 0      Linear Regression                       Baseline   859.281939
# 1          Decision Tree                       Baseline     0.000000
# 2                    SVR                       Baseline  1716.059980
# 3                   k-NN                       Baseline   773.838333
# 4          Random Forest                       Baseline   307.633542
# 5                XGBoost                       Baseline     5.945889
# 6               LightGBM                       Baseline   437.941413
# 7               CatBoost                       Baseline   123.638364
# 8          Decision Tree                     Stabilized   707.592570
# 9          Random Forest                     Stabilized   608.068712
# 10               XGBoost                     Stabilized    37.347328
# 11              LightGBM                     Stabilized   368.857442
# 12              CatBoost                     Stabilized   109.159958
# 13     Linear Regression                     Stabilized   859.281939
# 14                  k-NN                     Stabilized   795.725893
# 15                   SVR                     Stabilized   464.347225
# 16         Decision Tree               Reduced Features   853.659379
# 17         Random Forest               Reduced Features   746.465408
# 18              CatBoost               Reduced Features   274.623357
# 19                   SVR               Reduced Features   636.608415
# 20     Linear Regression               Reduced Features   902.768848
# 21                  k-NN               Reduced Features   798.713393
# 22  LightGBM (Optimized)                      Optimized   520.251346
# 23  CatBoost (Optimized)                      Optimized   112.458292
# 24                   SVR  Reduced Features+Optimization   636.608415
#
#         Val MAE  Train R2    Val R2  Train Time (s)  \
# 0   1341.873287  0.353380  0.221641          0.0030
# 1   1454.975000  1.000000 -0.805838          0.0086
# 2   1976.854782  0.004826 -0.002225          0.0119
# 3   1461.456667  0.487123  0.091054          0.0000
# 4   1304.098167  0.883017 -0.044472          0.2851
# 5   1459.346924  0.999993 -0.573390          0.0701
# 6   1200.831472  0.718793  0.250635          0.0310
# 7   1016.564289  0.997751  0.296183          1.3366
# 8   1270.124265  0.470122  0.204066          0.0043
# 9   1100.454092  0.547521  0.285295          0.1833
# 10  1203.684814  0.999793  0.123445          0.2382
# 11  1357.610999  0.883220  0.174405          0.0751
# 12  1000.621020  0.998198  0.314068          1.3406
# 13  1341.873287  0.353380  0.221641          0.0010
# 14  1237.861905  0.461550  0.367226          0.0010
# 15   984.390504  0.363713  0.264364          0.0150
# 16  1295.660322  0.379912  0.294862          0.0030
# 17  1295.291365  0.458854  0.323222          0.1155
# 18  1266.219826  0.988730  0.260171          1.2043
# 19  1175.492624  0.342374  0.205541          0.0140
# 20  1416.311151  0.330132  0.183316          0.0016
# 21  1246.660714  0.457854  0.348615          0.0010
# 22  1123.581035  0.596108  0.288561         88.7670
# 23   966.053678  0.998157  0.323849        292.6386
# 24  1175.492624  0.342374  0.205541          9.7955
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'colsample_bytree': 1.0, 'learnin...
# 23  GridSearch: {'depth': 8, 'iterations': 1500, '...
# 24  Feature selection + GridSearch: {'C': 1000, 'e...

# %% [markdown]
# ## Random Forest

# %%
# Define the parameter grid for Random Forest
param_grid_rf = {
    'n_estimators': [100, 300, 400, 500],        # Number of trees in the forest
    'max_depth': [None, 10, 12, 20],        # Depth of each tree
    'min_samples_split': [2, 5, 10],        # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4, 5],       # Minimum samples required at each leaf node
    'max_features': ['sqrt', 'log2', None]  # Number of features to consider at each split
}

# Initialize GridSearchCV
# Using n_jobs=-1 is highly recommended as Random Forest is computationally expensive
grid_rf = GridSearchCV(RandomForestRegressor(random_state=42), param_grid_rf, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1)

# Training
start = time.time()
# Train on the TRAINING set
grid_rf.fit(X_train_reduced, y_train)
end = time.time()
duration = end - start

# Get the best parameters and the best model
print("Best Parameters:", grid_rf.best_params_)
best_rf_model = grid_rf.best_estimator_

# Record and display the results
record_performance("Random Forest", best_rf_model, X_train_reduced, y_train, X_val_reduced, y_val, duration, notes=f"Feature selection +GridSearch: {grid_rf.best_params_}", step="Reduced Features+Optimization")
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 500}
#                    Model                           Step    Train MAE  \
# 0      Linear Regression                       Baseline   859.281939
# 1          Decision Tree                       Baseline     0.000000
# 2                    SVR                       Baseline  1716.059980
# 3                   k-NN                       Baseline   773.838333
# 4          Random Forest                       Baseline   307.633542
# 5                XGBoost                       Baseline     5.945889
# 6               LightGBM                       Baseline   437.941413
# 7               CatBoost                       Baseline   123.638364
# 8          Decision Tree                     Stabilized   707.592570
# 9          Random Forest                     Stabilized   608.068712
# 10               XGBoost                     Stabilized    37.347328
# 11              LightGBM                     Stabilized   368.857442
# 12              CatBoost                     Stabilized   109.159958
# 13     Linear Regression                     Stabilized   859.281939
# 14                  k-NN                     Stabilized   795.725893
# 15                   SVR                     Stabilized   464.347225
# 16         Decision Tree               Reduced Features   853.659379
# 17         Random Forest               Reduced Features   746.465408
# 18              CatBoost               Reduced Features   274.623357
# 19                   SVR               Reduced Features   636.608415
# 20     Linear Regression               Reduced Features   902.768848
# 21                  k-NN               Reduced Features   798.713393
# 22  LightGBM (Optimized)                      Optimized   520.251346
# 23  CatBoost (Optimized)                      Optimized   112.458292
# 24                   SVR  Reduced Features+Optimization   636.608415
# 25         Random Forest  Reduced Features+Optimization   698.210636
#
#         Val MAE  Train R2    Val R2  Train Time (s)  \
# 0   1341.873287  0.353380  0.221641          0.0030
# 1   1454.975000  1.000000 -0.805838          0.0086
# 2   1976.854782  0.004826 -0.002225          0.0119
# 3   1461.456667  0.487123  0.091054          0.0000
# 4   1304.098167  0.883017 -0.044472          0.2851
# 5   1459.346924  0.999993 -0.573390          0.0701
# 6   1200.831472  0.718793  0.250635          0.0310
# 7   1016.564289  0.997751  0.296183          1.3366
# 8   1270.124265  0.470122  0.204066          0.0043
# 9   1100.454092  0.547521  0.285295          0.1833
# 10  1203.684814  0.999793  0.123445          0.2382
# 11  1357.610999  0.883220  0.174405          0.0751
# 12  1000.621020  0.998198  0.314068          1.3406
# 13  1341.873287  0.353380  0.221641          0.0010
# 14  1237.861905  0.461550  0.367226          0.0010
# 15   984.390504  0.363713  0.264364          0.0150
# 16  1295.660322  0.379912  0.294862          0.0030
# 17  1295.291365  0.458854  0.323222          0.1155
# 18  1266.219826  0.988730  0.260171          1.2043
# 19  1175.492624  0.342374  0.205541          0.0140
# 20  1416.311151  0.330132  0.183316          0.0016
# 21  1246.660714  0.457854  0.348615          0.0010
# 22  1123.581035  0.596108  0.288561         88.7670
# 23   966.053678  0.998157  0.323849        292.6386
# 24  1175.492624  0.342374  0.205541          9.7955
# 25  1192.544590  0.527170  0.308031        143.6489
#
#                                                 Notes
# 0                      Default parameters, no scaling
# 1                      Default parameters, no scaling
# 2                      Default parameters, no scaling
# 3                      Default parameters, no scaling
# 4                      Default parameters, no scaling
# 5                      Default parameters, no scaling
# 6                      Default parameters, no scaling
# 7                      Default parameters, no scaling
# 8                                  Stabilized: Pruned
# 9                                  Stabilized: Pruned
# 10                  Stabilized: Pruned and randomized
# 11                              Stabilized: Throttled
# 12                            Stabilized: Regularized
# 13                                 Stabilized: Scaled
# 14                           Stabilized: Scaled + k=7
# 15                        Stabilized: Scaled + C=1000
# 16            Stabilized: Pruned and reduced features
# 17              Stabilized: Pruned + Reduced features
# 18         Stabilized: Regularized + Reduced features
# 19     Stabilized: Scaled + C=1000 + Reduced features
# 20              Stabilized: Scaled + Reduced features
# 21        Stabilized: Scaled + k=7 + reduced features
# 22  GridSearch: {'colsample_bytree': 1.0, 'learnin...
# 23  GridSearch: {'depth': 8, 'iterations': 1500, '...
# 24  Feature selection + GridSearch: {'C': 1000, 'e...
# 25  Feature selection +GridSearch: {'max_depth': 1...

# %% [markdown]
# # Show Feature Importance

# %%
best_model_name = get_performance_summary(sort_by="Val MAE").iloc[0]['Model']
best_model_step = get_performance_summary(sort_by="Val MAE").iloc[0]['Step']
print(f"Your best performing model is: {best_model_name} - {best_model_step}")
# Out:
# Your best performing model is: SVR - Optimized

# %%
# Select Best Model
winner_model = best_svr_model 
# Feature names for the best model
feature_names = X_train.columns

# %%
from sklearn.inspection import permutation_importance

# --- 1. Setup Data ---
# Select the correct validation set (Scaled for SVR/KNN/Linear, raw for Trees)
if any(m in best_model_name for m in ["SVR", "KNN", "Linear"]):
    X_to_use = X_val_scaled
else:
    X_to_use = X_val

# --- 2. Calculate Importance ---

# A. Tree-Based Models
if hasattr(winner_model, 'feature_importances_'):
    importances = winner_model.feature_importances_
    df_imp = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# B. Linear Models
elif hasattr(winner_model, 'coef_'):
    importances = np.abs(winner_model.coef_.flatten())
    df_imp = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# C. Black-Box Models (SVR, KNN)
else:
    print(f"Calculating Permutation Importance for {best_model_name}...")
    
    # SAFETY CHECK: Convert to values only if it is a DataFrame
    # This prevents the 'numpy.ndarray has no attribute values' error
    X_input = X_to_use.values if isinstance(X_to_use, pd.DataFrame) else X_to_use
    
    result = permutation_importance(
        winner_model, 
        X_input, 
        y_val, 
        n_repeats=10, 
        random_state=42, 
        scoring='neg_mean_absolute_error'
    )
    
    df_imp = pd.DataFrame({
        'Feature': feature_names, 
        'Importance': np.abs(result.importances_mean)
    })

# --- 3. Visualization ---
df_imp = df_imp.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(data=df_imp, x='Importance', y='Feature', hue='Feature', palette='magma', legend=False)

method = "Permutation" if "result" in locals() else "Direct"
plt.title(f"Feature Importance ({method}): {best_model_name}", fontsize=15, fontweight='bold')
plt.xlabel("Impact Magnitude (Effect on MAE)", fontsize=12)
plt.ylabel("Features", fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Calculating Permutation Importance for SVR...

# %% [markdown]
# # Test Best Models

# %%
# Re-initialize an empty list to store model performance
model_performance_list = []

# %% [markdown]
# ## SVR (optimized)

# %%
print(X_test_scaled.shape)
# Out:
# (132, 20)

# %%
# Prepare Test Data ---
# Use the same scaler instance that was fit on X_train. 
# X_test_processed = std_scaler.transform(X_test) 
# X_test_processed = X_test

# Generate Final Predictions ---
test_preds = best_svr_model.predict(X_test_scaled)


# Calculate Final Metrics
test_mae = mean_absolute_error(y_test, test_preds)
test_r2 = r2_score(y_test, test_preds)

# Validation Metrics
val_mae = get_performance_summary(sort_by="Val MAE").iloc[0]['Val MAE']
val_r2 = get_performance_summary(sort_by="Val R2").iloc[0]['Val R2']

print(f"======= FINAL PROJECT RESULTS: {best_model_name} =======")
print(f"Test MAE:  {test_mae:.2f} bikes")
print(f"Test R2:   {test_r2:.4f}")
print("=========================================================")

print(f"======= FINAL PROJECT RESULTS: {best_model_name} =======")
print(f"Val MAE:  {val_mae:.2f} bikes")
print(f"Val R2:   {val_r2:.4f}")
print("=========================================================")
# Out:
# ======= FINAL PROJECT RESULTS: SVR =======
# Test MAE:  760.64 bikes
# Test R2:   0.4392
# =========================================================
# ======= FINAL PROJECT RESULTS: SVR =======
# Val MAE:  928.14 bikes
# Val R2:   0.2962
# =========================================================
